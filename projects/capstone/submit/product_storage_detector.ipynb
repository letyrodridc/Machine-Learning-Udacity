# %% [markdown]
# <div align="center"><font size="6">Freeze-Non freeze Products Classifier</font></div>

# %% [markdown]
# # 1. The Precios Cuidados Dataset

# %% [markdown]
# ### Imports

# %% [markdown]
# In this section, I'm going to import all the required libraries for the Dataset preparation.
# I will use methods from:
#
# * python standard library
# * sklearn
# * numpy
# * matplotlib
# * pillow
# * openCV
# * h5py
# * Keras

# %%
from sklearn.datasets import load_files
from random import randint,shuffle
import matplotlib.pyplot as plt 
import numpy as np
import cv2
import PIL.Image
import h5py
from keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array,array_to_img
from keras.utils import to_categorical
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Loading the Dataset

# %% [markdown]
# In the `data_dir`, I have stored all the data images separated in two folders: fridge and non-fridge.
# I will use sklearn for loading the dataset. It will store the images and metadata information automatically, like the class of each image.

# %%
# Read the product images from the directory
data_dir  = "../data/preciosclaros_products"
bottleneck_features_dir = "../bottleneck_features"

print("Loading dataset from: ", data_dir,"\n")

# Store a sklearn dataset in raw_data. It includes metadata and the images.
raw_data = load_files(data_dir)
# Out:
# Loading dataset from:  ../data/preciosclaros_products

# %% [markdown]
# ### Exploring the Dataset

# %% [markdown]
# I will explore the dataset. I'm interested in how many images are in total and the quantity per class.

# %%
# Sklearn packged the images in a dictionary
print("Dataset keys: ",raw_data.keys())

# Reading the information form the sklearn dataset

# The list of filenames
filenames = raw_data['filenames']

# Each image to each class belogs. List of class_ids. 
target_classes = raw_data['target']

# The names of each class_id
target_names = raw_data['target_names']

# The files data, image data
data = raw_data['data']

raw_img_qty = len(filenames)

print("Dataset images qty:", raw_img_qty)
print("Classes qty:", len(target_names))
print("Classes names:", target_names)
print("\n")

print("# Products of each class:")

# I'm iterating the class_ids 
for c in range(len(target_names)):
    
    # filtering the products of the class_id c and taking lenght to know the quantity
    prod_qty = len([p for p in target_classes if p==c])
    print("{}: {} ({}%)".format(str(c)+": "+target_names[c], prod_qty, round(prod_qty/raw_img_qty,2)))
    

#  I will took a random image to know the shape    
raw_img_idx = randint(1,raw_img_qty)
filename = filenames[raw_img_idx]   
img = cv2.imread(filename)

print("\n")
print("Each image shape: ",img.shape)
# Out:
# Dataset keys:  dict_keys(['filenames', 'DESCR', 'target', 'target_names', 'data'])
# Dataset images qty: 4685
# Classes qty: 2
# Classes names: ['fridge', 'non_fridge']
#
#
# # Products of each class:
# 0: fridge: 683 (0.15%)
# 1: non_fridge: 4002 (0.85%)
#
#
# Each image shape:  (240, 240, 3)

# %% [markdown]
# Let sample some products to see the images quality and what is stored in the Dataset

# %%
# Dataset images sampling
fig=plt.figure(figsize=(20, 20))

# I will use a columns x rows grid for displaying the images
columns = 4
rows = 4
for i in range(1, columns*rows +1):
    
    # Using randint to select a random image
    raw_img_idx = randint(1,raw_img_qty)
    filename = filenames[raw_img_idx]
    target_class = target_classes[raw_img_idx]
    
    # Reading the image from file and applying a conversion, displaying images in matplotlib differs from storage.
    img = cv2.imread(filename)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    # I need to add a subplot for each image in matplot lib
    fig.add_subplot(rows, columns, i)
    
    # setting the title - I will use the classname
    plt.title(target_names[target_class])
    
    plt.imshow(img)
plt.show()

# %% [markdown]
# # 2. Dataset preparation

# %% [markdown]
# ### Spliting the dataset

# %% [markdown]
# First, I will define which percentage of the data will be destinated to train, validation, and test.

# %%
train_pct = 0.75
val_pct = 0.15
test_pct = 0.1

assert(train_pct+val_pct+test_pct==1.0)

# %% [markdown]
# Auxiliary methods

# %%
def split_train_val_test(ids, train_pct, val_pct):
    '''
    Splits the ids in train, valid, and test according to the specified percentages.
    
    Input:  ids - set of data indexes
            train_pct - % destinated to the train set
            val_pct - % destinated to the validation set
    
    Output: Tuple (train set, validation set, test set)
            Each component a list of ids
            
    '''
    total = len(ids)

    shuffle(ids)

    train_idx = int(train_pct*total)
    val_idx = int(val_pct*total)


    train_set  = ids[0:train_idx]
    val_set    = ids[train_idx:train_idx+val_idx]
    test_set  = ids[train_idx+val_idx:]
    
    return train_set, val_set, test_set

def merge_sets_and_shuffle(set1, set2):
    '''
    Merges two lists and returns shuffled the result
    '''
    set1 = set1+set2
    shuffle(set1)
    return set1

def get_set_stats(target_set, target_set_fridge, target_set_non_fridge, total):
    '''
    Returns the stats for a set (tuple):
        total
        percentage over all the images
        fridge quantity
        percentage fridge over total
        non-frige qty
        percentage non-fridge over total
    '''
    fridge_qty     = len(target_set_fridge) 
    non_fridge_qty = len(target_set_non_fridge)
    total_set = len(target_set)
    
    pct_total = round(total_set/total,2)
    pct_fridge = round(fridge_qty/total_set,2)
    pct_non_fridge= round(non_fridge_qty/total_set,2)
    
    return total_set, pct_total, fridge_qty, pct_fridge, non_fridge_qty, pct_non_fridge

# %%
## The idea is to build the sets keeping the proporsion of each class

# Separates the ids of the images according the class
fridge_ids     = [i for i,p in enumerate(target_classes) if p==0] 
non_fridge_ids = [i for i,p in enumerate(target_classes) if p==1] 


use_equal_parts = True
if use_equal_parts:
    non_fridge_ids = non_fridge_ids[:len(fridge_ids)]        

    
total = len(non_fridge_ids)+len(fridge_ids)

# Divides in sets according the percentage destinated for train, validation, and test set
train_set0, valid_set0, test_set0 = split_train_val_test(fridge_ids,train_pct,val_pct)
train_set1, valid_set1, test_set1 = split_train_val_test(non_fridge_ids,train_pct,val_pct)

# Merges both classes train, valid, and test sets to build a unique train, test, and valid set
train_set_ids = merge_sets_and_shuffle(train_set0, train_set1) 
valid_set_ids = merge_sets_and_shuffle(valid_set0, valid_set1) 
test_set_ids  = merge_sets_and_shuffle(test_set0, test_set1) 

# Priting some stats to see the results
print("Resultant sets stats:")


st = get_set_stats(train_set_ids, train_set0, train_set1, total)
print("Train Set: Total={} ({}%) , Fridge={} ({}%), Non-Frige={} ({}%)".format(*st))

st = get_set_stats(valid_set_ids, valid_set0, valid_set1, total)
print("Valid Set:  Total={} ({}%) , Fridge={} ({}%), Non-Frige={} ({}%)".format(*st))

st = get_set_stats(test_set_ids, test_set0, test_set1, total)
print("Test Set: Total={} ({}%) , Fridge={} ({}%), Non-Frige={} ({}%)".format(*st))
# Out:
# Resultant sets stats:
# Train Set: Total=1024 (0.75%) , Fridge=512 (0.5%), Non-Frige=512 (0.5%)
# Valid Set:  Total=204 (0.15%) , Fridge=102 (0.5%), Non-Frige=102 (0.5%)
# Test Set: Total=138 (0.1%) , Fridge=69 (0.5%), Non-Frige=69 (0.5%)

# %% [markdown]
# ### Loading the images and labels (without data augmentation in memory)

# %%
tgt_image_size = (224,224,3)

def load_images_from_files(ids):
    '''
    Takes a list of images ids and returns the image data and label.
    It will resize it to 224x224x3 so it can be used in pre-trained models.
    
    Input:  ids - set of data indexes
    
    Output: Tuple (images, labels)
            images contains a list of 224x224x3 images
            labels contains a list of 0 (fridge) or 1 (non-fridge) indicating the class of the image i
    '''       
   
  
    # I'm creating empty numpy arrays, one for holding the images and the other one to hold the labels
    # I set the target shape
    images = np.ndarray(shape=(len(ids),)+tgt_image_size,dtype=float)
    labels = np.ndarray(shape=(len(ids),))
    
    for i, img_nbr in enumerate(ids):
        
        # I read the image data
        img = load_img(filenames[img_nbr])
        
        # Resizes the image       
        img = img.resize(tgt_image_size[:2])
        x = img_to_array(img)  
        
        # Update the numpy arrays with the image data and labels
        images[i] = x
        labels[i] = target_classes[img_nbr]
    
    labels = to_categorical(labels, len(target_names))
    return images,labels

# %% [markdown]
# Using the Ids I've separated, I will load all the images and labels information.

# %%
reload = True

if reload:
    # Loads from disk the image and labels for each train image
    pre_X_train,pre_y_train = load_images_from_files(train_set_ids)

    # Loads from disk the image and labels for each validation image
    pre_X_valid,pre_y_valid  = load_images_from_files(valid_set_ids)

    # Loads from disk the image and labels for each test image
    pre_X_test,pre_y_test  = load_images_from_files(test_set_ids)

    


print("-- Pre processed Train dataset --")
print("Dataset shape: ", pre_X_train.shape)
print("Labels shape:", pre_y_train.shape)

print("-- Pre processed Test dataset --")
print("Dataset shape: ", pre_X_valid.shape)
print("Labels shape:", pre_y_valid.shape)

print("-- Pre processed Validate  dataset --")
print("Dataset shape: ", pre_X_test.shape)
print("Labels shape:", pre_y_test.shape)
# Out:
# -- Pre processed Train dataset --
# Dataset shape:  (1024, 224, 224, 3)
# Labels shape: (1024, 2)
# -- Pre processed Test dataset --
# Dataset shape:  (204, 224, 224, 3)
# Labels shape: (204, 2)
# -- Pre processed Validate  dataset --
# Dataset shape:  (138, 224, 224, 3)
# Labels shape: (138, 2)

# %% [markdown]
# ### Define the data transformation to be applied (Data Augmentation)

# %%
import PIL.Image
from keras.applications.vgg19 import preprocess_input
datagen = ImageDataGenerator(
        rotation_range=10,
        #width_shift_range=0.2,
        #height_shift_range=0.2,
        shear_range=0.5,
        zoom_range=[1,2.5],
        rescale=1./255,
        #preprocessing_function=preprocess_input,
        #horizontal_flip=True,
        fill_mode='nearest')

e = np.ndarray(shape=(10,240,240,3))
j = 0
for i in test_set_ids[1:11]:
    img = load_img(filenames[i])  
    x = img_to_array(img)  
    e[j] = x
    j=j+1

fig=plt.figure(figsize=(20, 20))
columns = 10
rows = 10

j = 0
for batch in datagen.flow(e, batch_size=1, shuffle=False):
    j += 1
    if j > 40:
        break 
        
    xi = array_to_img(batch[0])
    fig.add_subplot(rows, columns, j)

    plt.imshow(xi)
        
        
plt.show()

# %% [markdown]
# ### The data generators creation (Data Augmentation)

# %%
train_datagen = datagen 

valid_datagen = ImageDataGenerator(rescale=1./255)

test_datagen = ImageDataGenerator(rescale=1./255)

train_datagen.fit(pre_X_train)
valid_datagen.fit(pre_X_valid)
test_datagen.fit(pre_X_test)

# %% [markdown]
# ## 3. Model Building: Benchmark Model

# %% [markdown]
# ### Modeling imports

# %%
from keras.layers import  Dense, GlobalAveragePooling2D, Flatten, Dropout, Conv2D,MaxPooling2D
from keras.models import Sequential
from keras.callbacks import ModelCheckpoint
from keras.optimizers import SGD,Adamax,Adagrad
from keras.applications.vgg19 import VGG19
from keras.applications.vgg16 import VGG16
from keras.applications.resnet50 import ResNet50
from keras.applications.xception import Xception
from keras.applications.inception_v3 import InceptionV3
from math import ceil

# %% [markdown]
# ### Bottleneck features extraction : data preprocessing

# %%
def extract_features(datagen, pre_trained_model_type, X, y, batch_size, aug_images_nbr, filename):
    generator = datagen.flow(X, y, batch_size=batch_size, shuffle=False)

    model = pre_trained_model_type(input_shape=X.shape[1:],include_top=False)
    model.compile(optimizer='rmsprop', loss='categorical_crossentropy')
    bottleneck_features = model.predict_generator(generator,  steps=aug_images_nbr*len(X)//batch_size, max_queue_size=10, workers=1, use_multiprocessing=True, verbose=1)
    print("Bottleneck features shape: ",bottleneck_features.shape)
    np.save(filename, bottleneck_features)

# %%
def generate_bottleneck_features(model_type, batch_size=32, data_augmented_images=8):
    model_name = model_type.__name__
    print("Generating features for model "+model_name)
    extract_features(train_datagen, model_type, pre_X_train, pre_y_train,batch_size, data_augmented_images,model_name+"_train.npy")
    extract_features(valid_datagen, model_type, pre_X_valid, pre_y_valid,batch_size, data_augmented_images,model_name+"_valid.npy")
    extract_features(test_datagen, model_type, pre_X_test, pre_y_test,batch_size, 1,model_name+"_test.npy")
 
#generate_bottleneck_features(VGG19)
generate_bottleneck_features(VGG16)
#generate_bottleneck_features(ResNet50)
#generate_bottleneck_features(Xception,data_augmented_images=4)
#generate_bottleneck_features(InceptionV3)
# Out:
# Generating features for model VGG16
# 256/256 [==============================] - 61s 239ms/step
# Bottleneck features shape:  (8192, 7, 7, 512)
# 51/51 [==============================] - 8s 157ms/step
# Bottleneck features shape:  (1492, 7, 7, 512)
# 4/4 [==============================] - 1s 177ms/step
# Bottleneck features shape:  (128, 7, 7, 512)

# %% [markdown]
# ### Benchmark Model

# %%
model_type = VGG16

def load_bottleneck(filename,pre_y):
    X = np.load(filename)
    
    labels_length = len(pre_y)
    X_length = len(X)
    
    times = ceil(X_length / labels_length)
    
    y = np.tile(pre_y, (times,1))[:X_length]
    
    return X,y

def load_bottleneck_class(model_type):
    model_name = model_type.__name__
    X_train, y_train = load_bottleneck(model_name+"_train.npy",pre_y_train)
    X_valid, y_valid = load_bottleneck(model_name+"_valid.npy",pre_y_train)
    X_test, y_test = load_bottleneck(model_name+"_test.npy",pre_y_train)
    
    return  X_train, y_train, X_valid, y_valid, X_test, y_test

X_train, y_train, X_valid, y_valid, X_test, y_test = load_bottleneck_class(model_type)

# %%
bench_model = Sequential()
bench_model.add(GlobalAveragePooling2D(input_shape=X_train.shape[1:]))
bench_model.add(Dense(2, activation='softmax'))
bench_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# global_average_pooling2d_1 ( (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 1,026
# Trainable params: 1,026
# Non-trainable params: 0
# _________________________________________________________________

# %%
have_to_train_benchmark = True
def train_benchmark(filename):

    epochs = 200
    batch_size = 64


    sgd = SGD(lr=0.001, decay=1e-6, momentum=0.9, nesterov=True)
    #adamax = Adamax(lr=0.01, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0)
    bench_model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

    
    if have_to_train_benchmark:
        checkpoint = ModelCheckpoint(filename, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
        callbacks_list = [checkpoint]


        bench_model.fit(X_train, y_train,
                  epochs=epochs,
                  batch_size=batch_size, validation_data=(X_valid, y_valid), callbacks=callbacks_list)

def train_benchmark_model(model_type, load_bottleneck=True):
    if load_bottleneck:
        load_bottleneck_class(model_type)
        
    model_name = model_type.__name__
    train_benchmark(model_name+".weights.best.hdf5")
        
train_benchmark_model(model_type)
# Out:
# Train on 8192 samples, validate on 1492 samples
# Epoch 1/200
# 8192/8192 [==============================] - 1s 72us/step - loss: 0.7020 - acc: 0.5006 - val_loss: 0.6986 - val_acc: 0.5101
#
# Epoch 00001: val_acc improved from -inf to 0.51005, saving model to VGG16.weights.best.hdf5
# Epoch 2/200
# 8192/8192 [==============================] - 0s 53us/step - loss: 0.6825 - acc: 0.5576 - val_loss: 0.7017 - val_acc: 0.4859
#
# Epoch 00002: val_acc did not improve
# Epoch 3/200
# 8192/8192 [==============================] - 0s 60us/step - loss: 0.6728 - acc: 0.5930 - val_loss: 0.7019 - val_acc: 0.4913
#
# Epoch 00003: val_acc did not improve
# Epoch 4/200
# 8192/8192 [==============================] - 1s 63us/step - loss: 0.6625 - acc: 0.6246 - val_loss: 0.7094 - val_acc: 0.4886
#
# Epoch 00004: val_acc did not improve
# Epoch 5/200
# 8192/8192 [==============================] - 1s 68us/step - loss: 0.6557 - acc: 0.6331 - val_loss: 0.7113 - val_acc: 0.4960
#
# Epoch 00005: val_acc did not improve
# Epoch 6/200
# 8192/8192 [==============================] - 0s 58us/step - loss: 0.6473 - acc: 0.6515 - val_loss: 0.7151 - val_acc: 0.4792
#
# Epoch 00006: val_acc did not improve
# Epoch 7/200
# 8192/8192 [==============================] - 0s 58us/step - loss: 0.6410 - acc: 0.6650 - val_loss: 0.7229 - val_acc: 0.4966
#
# Epoch 00007: val_acc did not improve
# Epoch 8/200
# 8192/8192 [==============================] - 0s 58us/step - loss: 0.6355 - acc: 0.6670 - val_loss: 0.7253 - val_acc: 0.4792
#
# Epoch 00008: val_acc did not improve
# Epoch 9/200
# 8192/8192 [==============================] - 0s 58us/step - loss: 0.6303 - acc: 0.6798 - val_loss: 0.7325 - val_acc: 0.4906
#
# Epoch 00009: val_acc did not improve
# Epoch 10/200
# 8192/8192 [==============================] - 0s 58us/step - loss: 0.6256 - acc: 0.6858 - val_loss: 0.7435 - val_acc: 0.4893
#
# Epoch 00010: val_acc did not improve
# Epoch 11/200
# 8192/8192 [==============================] - 0s 58us/step - loss: 0.6210 - acc: 0.6893 - val_loss: 0.7424 - val_acc: 0.4886
#
# Epoch 00011: val_acc did not improve
# Epoch 12/200
# 8192/8192 [==============================] - 0s 59us/step - loss: 0.6176 - acc: 0.6909 - val_loss: 0.7509 - val_acc: 0.4873
#
# Epoch 00012: val_acc did not improve
# Epoch 13/200
# 8192/8192 [==============================] - 1s 71us/step - loss: 0.6135 - acc: 0.6896 - val_loss: 0.7548 - val_acc: 0.4839
#
# Epoch 00013: val_acc did not improve
# Epoch 14/200
# 8192/8192 [==============================] - 1s 71us/step - loss: 0.6105 - acc: 0.6967 - val_loss: 0.7637 - val_acc: 0.4859
#
# Epoch 00014: val_acc did not improve
# Epoch 15/200
# 8192/8192 [==============================] - 0s 55us/step - loss: 0.6074 - acc: 0.7008 - val_loss: 0.7653 - val_acc: 0.4819
#
# Epoch 00015: val_acc did not improve
# Epoch 16/200
# 8192/8192 [==============================] - 0s 55us/step - loss: 0.6040 - acc: 0.7040 - val_loss: 0.7705 - val_acc: 0.4819
#
# Epoch 00016: val_acc did not improve
# Epoch 17/200
# 8192/8192 [==============================] - 0s 57us/step - loss: 0
200
# 8192/8192 [==============================] - 0s 58us/step - loss: 0.5610 - acc: 0.7344 - val_loss: 0.8292 - val_acc: 0.4866
#
# Epoch 00038: val_acc did not improve
# Epoch 39/200
# 8192/8192 [==============================] - 0s 58us/step - loss: 0.5590 - acc: 0.7380 - val_loss: 0.8320 - val_acc: 0.4846
#
# Epoch 00039: val_acc did not improve
# Epoch 40/200
# 8192/8192 [==============================] - 0s 58us/step - loss: 0.5579 - acc: 0.7361 - val_loss: 0.8315 - val_acc: 0.4832
#
# Epoch 00040: val_acc did not improve
# Epoch 41/200
# 8192/8192 [==============================] - 0s 59us/step - loss: 0.5568 - acc: 0.7416 - val_loss: 0.8319 - val_acc: 0.4920
#
# Epoch 00041: val_acc did not improve
# Epoch 42/200
# 8192/8192 [==============================] - 0s 58us/step - loss: 0.5559 - acc: 0.7378 - val_loss: 0.8377 - val_acc: 0.4893
#
# Epoch 00042: val_acc did not improve
# Epoch 43/200
# 8192/8192 [==============================] - 0s 59us/step - loss: 0.5540 - acc: 0.7400 - val_loss: 0.8394 - val_acc: 0.4866
#
# Epoch 00043: val_acc did not improve
# Epoch 44/200
# 8192/8192 [==============================] - 1s 69us/step - loss: 0.5523 - acc: 0.7437 - val_loss: 0.8422 - val_acc: 0.4873
#
# Epoch 00044: val_acc did not improve
# Epoch 45/200
# 8192/8192 [==============================] - 1s 62us/step - loss: 0.5514 - acc: 0.7400 - val_loss: 0.8470 - val_acc: 0.4819
#
# Epoch 00045: val_acc did not improve
# Epoch 46/200
# 8192/8192 [==============================] - 1s 62us/step - loss: 0.5500 - acc: 0.7441 - val_loss: 0.8422 - val_acc: 0.4839
#
# Epoch 00046: val_acc did not improve
# Epoch 47/200
# 8192/8192 [==============================] - 1s 62us/step - loss: 0.5497 - acc: 0.7407 - val_loss: 0.8472 - val_acc: 0.4859
#
# Epoch 00047: val_acc did not improve
# Epoch 48/200
# 8192/8192 [==============================] - 0s 57us/step - loss: 0.5472 - acc: 0.7441 - val_loss: 0.8442 - val_acc: 0.4913
#
# Epoch 00048: val_acc did not improve
# Epoch 49/200
# 8192/8192 [==============================] - 1s 70us/step - loss: 0.5464 - acc: 0.7429 - val_loss: 0.8455 - val_acc: 0.4913
#
# Epoch 00049: val_acc did not improve
# Epoch 50/200
# 8192/8192 [==============================] - 1s 70us/step - loss: 0.5450 - acc: 0.7445 - val_loss: 0.8478 - val_acc: 0.4873
#
# Epoch 00050: val_acc did not improve
# Epoch 51/200
# 8192/8192 [==============================] - 1s 72us/step - loss: 0.5439 - acc: 0.7445 - val_loss: 0.8544 - val_acc: 0.4859
#
# Epoch 00051: val_acc did not improve
# Epoch 52/200
# 8192/8192 [==============================] - 1s 68us/step - loss: 0.5433 - acc: 0.7430 - val_loss: 0.8532 - val_acc: 0.4806
#
# Epoch 00052: val_acc did not improve
# Epoch 53/200
# 8192/8192 [==============================] - 1s 69us/step - loss: 0.5422 - acc: 0.7482 - val_loss: 0.8613 - val_acc: 0.4873
#
# Epoch 00053: val_acc did not improve
# Epoch 54/200
# 8192/8192 [==============================] - 1s 62us/step - loss: 0.5417 - acc: 0.7452 - val_loss: 0.8524 - val_acc: 0.4906
#
# Epoch 00054: val_acc did not improve
# Epoch 55/200
# 8192/8192 [==============================] - 0s 59us/step - loss: 0.5410 - acc: 0.7460 - val_loss: 0.8583 - val_acc: 0.4846
#
# Epoch 00055: val_acc did not improve
# Epoch 56/200
# 8192/8192 [==============================] - 1s 71us/step - loss: 0.5389 - acc: 0.7498 - val_loss: 0.8602 - val_acc: 0.4859
#
# Epoch 00056: val_acc did not improve
# Epoch 57/200
# 8192/8192 [==============================] - 1s 70us/step - loss: 0.5382 - acc: 0.7468 - val_loss: 0.8565 - val_acc: 0.4933
#
# Epoch 00057: val_acc did not improve
# Epoch 58/200
# 8192/8192 [==============================] - 0s 56us/step - loss: 0.5369 - acc: 0.7502 - val_loss: 0.8675 - val_acc: 0.4873
#
# Epoch 00058: val_acc did not improve
# Epoch 59/200
# 8192/8192 [==============================] - 1s 61us/step - loss: 0.5359 - acc: 0.7502 - val_loss: 0.8602 - val_acc: 0.4866
#
# Epoch 00059: val_acc did not improve
# Epoch 60/200
# 8192/8192 [==============================] - 1s 61us/step - loss: 0.5352 - acc: 0.7516 - val_loss: 0.8642 - val_acc: 0.4779
#
# Epoch 00060: val_acc did not improve
# Epoch 61/200
# 8192/8192 [==============================] - 1s 62us/step - loss: 0.5341 - acc: 0.7522 - val_loss: 0.8632 - val_acc: 0.4866
#
# Epoch 00061: val_acc did not improve
# Epoch 62/200
# 8192/8192 [==============================] - 1s 63us/step - loss: 0.5334 - acc: 0.7533 - val_loss: 0.8639 - val_acc: 0.4913
#
# Epoch 00062: val_acc did not improve
# Epoch 63/200
# 8192/8192 [==============================] - 1s 90us/step - loss: 0.5329 - acc: 0.7526 - val_loss: 0.8690 - val_acc: 0.4786
#
# Epoch 00063: val_acc did not improve
# Epoch 64/200
# 8192/8192 [==============================] - 1s 75us/step - loss: 0.5314 - acc: 0.7535 - val_loss: 0.8717 - val_acc: 0.4886
#
# Epoch 00064: val_acc did not improve
# Epoch 65/200
# 8192/8192 [==============================] - 1s 68us/step - loss: 0.5316 - acc: 0.7510 - val_loss: 0.8675 - val_acc: 0.4913
#
# Epoch 00065: val_acc did not improve
# Epoch 66/200
# 8192/8192 [==============================] - 0s 49us/step - loss: 0.5299 - acc: 0.7524 - val_loss: 0.8719 - val_acc: 0.4853
#
# Epoch 00066: val_acc did not improve
# Epoch 67/200
# 8192/8192 [==============================] - 0s 54us/step - loss: 0.5295 - acc: 0.7505 - val_loss: 0.8709 - val_acc: 0.4846
#
# Epoch 00067: val_acc did not improve
# Epoch 68/200
# 8192/8192 [==============================] - 0s 55us/step - loss: 0.5284 - acc: 0.7563 - val_loss: 0.8701 - val_acc: 0.4913
#
# Epoch 00068: val_acc did not improve
# Epoch 69/200
# 8192/8192 [==============================] - 0s 57us/step - loss: 0.5271 - acc: 0.7532 - val_loss: 0.8829 - val_acc: 0.4839
#
# Epoch 00069: val_acc did not improve
# Epoch 70/200
# 8192/8192 [==============================] - 0s 58us/step - loss: 0.5267 - acc: 0.7535 - val_loss: 0.8729 - val_acc: 0.4893
#
# Epoch 00070: val_acc did not improve
# Epoch 71/200
# 8192/8192 [==============================] - 0s 51us/step - loss: 0.5256 - acc: 0.7584 - val_loss: 0.8747 - val_acc: 0.4913
#
# Epoch 00071: val_acc did not improve
# Epoch 72/200
# 8192/8192 [==============================] - 1s 65us/step - loss: 0.5247 - acc: 0.7598 - val_loss: 0.8745 - val_acc: 0.4913
#
# Epoch 00072: val_acc did not improve
# Epoch 73/200
# 8192/8192 [==============================] - 1s 66us/step - loss: 0.5237 - acc: 0.7587 - val_loss: 0.8840 - val_acc: 0.4832
#
# Epoch 00073: val_acc did not improve
# Epoch 74/200
# 8192/8192 [==============================] - 1s 66us/step - loss: 0.5237 - acc: 0.7542 - val_loss: 0.8792 - val_acc: 0.4893
#
# Epoch 00074: val_acc did not improve
# Epoch 75/200
# 8192/8192 [==============================] - 1s 66us/step - loss: 0.5230 - acc: 0.7561 - val_loss: 0.8791 - val_acc: 0.4893
#
# Epoch 00075: val_acc did not improve
# Epoch 76/200
# 8192/8192 [==============================] - 1s 61us/step - loss: 0.5211 - acc: 0.7614 - val_loss: 0.8793 - val_acc: 0.4893
#
# Epoch 00076: val_acc did not improve
# Epoch 77/200
# 8192/8192 [==============================] - 0s 51us/step - loss: 0
200
# 8192/8192 [==============================] - 0s 57us/step - loss: 0.4650 - acc: 0.7892 - val_loss: 0.9663 - val_acc: 0.4899
#
# Epoch 00192: val_acc did not improve
# Epoch 193/200
# 8192/8192 [==============================] - 0s 61us/step - loss: 0.4642 - acc: 0.7916 - val_loss: 0.9623 - val_acc: 0.4926
#
# Epoch 00193: val_acc did not improve
# Epoch 194/200
# 8192/8192 [==============================] - 0s 57us/step - loss: 0.4649 - acc: 0.7919 - val_loss: 0.9624 - val_acc: 0.4920
#
# Epoch 00194: val_acc did not improve
# Epoch 195/200
# 8192/8192 [==============================] - 1s 67us/step - loss: 0.4644 - acc: 0.7919 - val_loss: 0.9671 - val_acc: 0.4893
#
# Epoch 00195: val_acc did not improve
# Epoch 196/200
# 8192/8192 [==============================] - 1s 68us/step - loss: 0.4631 - acc: 0.7919 - val_loss: 0.9704 - val_acc: 0.4853
#
# Epoch 00196: val_acc did not improve
# Epoch 197/200
# 8192/8192 [==============================] - 1s 68us/step - loss: 0.4632 - acc: 0.7911 - val_loss: 0.9661 - val_acc: 0.4906
#
# Epoch 00197: val_acc did not improve
# Epoch 198/200
# 8192/8192 [==============================] - 1s 68us/step - loss: 0.4631 - acc: 0.7919 - val_loss: 0.9736 - val_acc: 0.4772
#
# Epoch 00198: val_acc did not improve
# Epoch 199/200
# 8192/8192 [==============================] - 1s 68us/step - loss: 0.4629 - acc: 0.7909 - val_loss: 0.9656 - val_acc: 0.4926
#
# Epoch 00199: val_acc did not improve
# Epoch 200/200
# 8192/8192 [==============================] - 1s 68us/step - loss: 0.4618 - acc: 0.7921 - val_loss: 0.9662 - val_acc: 0.4926
#
# Epoch 00200: val_acc did not improve

# %% [markdown]
# ## 4. Model Building: Product detector from the scratch

# %% [markdown]
# ### Preparing Data Generators for Data Augmentation

# %%
batch_size = 128
train_generator = train_datagen.flow(pre_X_train, pre_y_train, batch_size=batch_size, shuffle=False)
valid_generator = valid_datagen.flow(pre_X_valid, pre_y_valid, batch_size=batch_size, shuffle=False)
test_generator = test_datagen.flow(pre_X_test, pre_y_test, batch_size=batch_size, shuffle=False)

# %% [markdown]
# ### Defining the model

# %%
model = Sequential()

model.add(Conv2D(filters=16, kernel_size=2, strides=1, activation='relu', input_shape=(224, 224, 3)))
model.add(MaxPooling2D(pool_size=2, strides=2))
model.add(Conv2D(filters=32, kernel_size=2, strides=1, activation='relu'))
model.add(MaxPooling2D(pool_size=2, strides=2))
model.add(Conv2D(filters=64, kernel_size=2, strides=1, activation='relu'))
model.add(MaxPooling2D(pool_size=2, strides=2))
#model.add(Dense(64,activation='relu'))
model.add(Dropout(0.5))
model.add(Conv2D(filters=128, kernel_size=2, strides=1, activation='relu'))
model.add(MaxPooling2D(pool_size=2, strides=2))
model.add(Flatten())
model.add(Dense(256,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(128,activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(2, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 223, 223, 16)      208
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 111, 111, 16)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 110, 110, 32)      2080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 55, 55, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 54, 54, 64)        8256
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 27, 27, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 27, 27, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 26, 26, 128)       32896
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 13, 13, 128)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 21632)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               5538048
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 5,622,770
# Trainable params: 5,622,770
# Non-trainable params: 0
# _________________________________________________________________

# %%
'''
model = Sequential()

model.add(Conv2D(filters=16, kernel_size=2, strides=1, activation='relu', input_shape=(224, 224, 3)))
model.add(MaxPooling2D(pool_size=2, strides=2))
model.add(Conv2D(filters=32, kernel_size=2, strides=1, activation='relu'))
model.add(MaxPooling2D(pool_size=2, strides=2))
model.add(Conv2D(filters=64, kernel_size=2, strides=1, activation='relu'))
model.add(MaxPooling2D(pool_size=2, strides=2))
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.5))
model.add(Conv2D(filters=128, kernel_size=2, strides=1, activation='relu'))
model.add(MaxPooling2D(pool_size=2, strides=2))
model.add(Flatten())
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(2, activation='softmax'))

model.summary()
'''
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_9 (Conv2D)            (None, 223, 223, 16)      208
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 111, 111, 16)      0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 110, 110, 32)      2080
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 55, 55, 32)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 54, 54, 64)        8256
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 27, 27, 64)        0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 27, 27, 64)        0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 26, 26, 128)       32896
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 13, 13, 128)       0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 21632)             0
# _________________________________________________________________
# dense_7 (Dense)              (None, 128)               2769024
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 2,820,850
# Trainable params: 2,820,850
# Non-trainable params: 0
# _________________________________________________________________
# "\nmodel = Sequential()\n\nmodel.add(Conv2D(filters=16, kernel_size=2, strides=1, activation='relu', input_shape=(224, 224, 3)))\nmodel.add(MaxPooling2D(pool_size=2, strides=2))\nmodel.add(Conv2D(filters=32, kernel_size=2, strides=1, activation='relu'))\nmodel.add(MaxPooling2D(pool_size=2, strides=2))\nmodel.add(Conv2D(filters=64, kernel_size=2, strides=1, activation='relu'))\nmodel.add(MaxPooling2D(pool_size=2, strides=2))\nmodel.add(Dense(64,activation='relu'))\nmodel.add(Dropout(0.5))\nmodel.add(Conv2D(filters=128, kernel_size=2, strides=1, activation='relu'))\nmodel.add(MaxPooling2D(pool_size=2, strides=2))\nmodel.add(Flatten())\nmodel.add(Dense(64,activation='relu'))\nmodel.add(Dropout(0.2))\nmodel.add(Dense(2, activation='softmax'))\n\nmodel.summary()\n"

# %% [markdown]
# ### Training the model

# %%
train_model = True
epochs = 300
val_epochs=800
batch_size = 64

#sgd = SGD(lr=0.001, decay=1e-6, momentum=0.9, nesterov=True)
adamax = Adamax(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0)
model.compile(loss='categorical_crossentropy', optimizer=adamax, metrics=['accuracy'])

if train_model:
    filepath="model_weights.best.hdf5"
    
    checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
    callbacks_list = [checkpoint]
    
    model.fit_generator(
            train_generator,
            steps_per_epoch=epochs // batch_size,
            epochs=epochs,
            callbacks=callbacks_list,
            validation_data=valid_generator,
            validation_steps=800 // batch_size)
# Out:
# Epoch 1/300
# 4/4 [==============================] - 4s 1s/step - loss: 0.7051 - acc: 0.4980 - val_loss: 0.6935 - val_acc: 0.4951
#
# Epoch 00001: val_acc improved from -inf to 0.49510, saving model to model_weights.best.hdf5
# Epoch 2/300
# 4/4 [==============================] - 3s 818ms/step - loss: 0.7034 - acc: 0.4805 - val_loss: 0.6936 - val_acc: 0.5000
#
# Epoch 00002: val_acc improved from 0.49510 to 0.50000, saving model to model_weights.best.hdf5
# Epoch 3/300
# 4/4 [==============================] - 4s 888ms/step - loss: 0.7057 - acc: 0.4863 - val_loss: 0.6940 - val_acc: 0.5000
#
# Epoch 00003: val_acc did not improve
# Epoch 4/300
# 4/4 [==============================] - 3s 872ms/step - loss: 0.7178 - acc: 0.4551 - val_loss: 0.6935 - val_acc: 0.4853
#
# Epoch 00004: val_acc did not improve
# Epoch 5/300
# 4/4 [==============================] - 3s 873ms/step - loss: 0.6968 - acc: 0.5273 - val_loss: 0.6934 - val_acc: 0.4853
#
# Epoch 00005: val_acc did not improve
# Epoch 6/300
# 4/4 [==============================] - 4s 878ms/step - loss: 0.7042 - acc: 0.4805 - val_loss: 0.6933 - val_acc: 0.4902
#
# Epoch 00006: val_acc did not improve
# Epoch 7/300
# 4/4 [==============================] - 4s 887ms/step - loss: 0.6946 - acc: 0.5234 - val_loss: 0.6935 - val_acc: 0.4902
#
# Epoch 00007: val_acc did not improve
# Epoch 8/300
# 4/4 [==============================] - 3s 874ms/step - loss: 0.6982 - acc: 0.5137 - val_loss: 0.6935 - val_acc: 0.5049
#
# Epoch 00008: val_acc improved from 0.50000 to 0.50490, saving model to model_weights.best.hdf5
# Epoch 9/300
# 4/4 [==============================] - 4s 892ms/step - loss: 0.6882 - acc: 0.5391 - val_loss: 0.6936 - val_acc: 0.4461
#
# Epoch 00009: val_acc did not improve
# Epoch 10/300
# 4/4 [==============================] - 3s 871ms/step - loss: 0.7008 - acc: 0.4863 - val_loss: 0.6935 - val_acc: 0.4167
#
# Epoch 00010: val_acc did not improve
# Epoch 11/300
# 4/4 [==============================] - 4s 876ms/step - loss: 0.6960 - acc: 0.5293 - val_loss: 0.6935 - val_acc: 0.4559
#
# Epoch 00011: val_acc did not improve
# Epoch 12/300
# 4/4 [==============================] - 3s 873ms/step - loss: 0.6962 - acc: 0.5273 - val_loss: 0.6935 - val_acc: 0.4608
#
# Epoch 00012: val_acc did not improve
# Epoch 13/300
# 4/4 [==============================] - 4s 881ms/step - loss: 0.6980 - acc: 0.4883 - val_loss: 0.6935 - val_acc: 0.4559
#
# Epoch 00013: val_acc did not improve
# Epoch 14/300
# 4/4 [==============================] - 3s 873ms/step - loss: 0.6980 - acc: 0.5059 - val_loss: 0.6934 - val_acc: 0.4265
#
# Epoch 00014: val_acc did not improve
# Epoch 15/300
# 4/4 [==============================] - 4s 877ms/step - loss: 0.7045 - acc: 0.4785 - val_loss: 0.6933 - val_acc: 0.4804
#
# Epoch 00015: val_acc did not improve
# Epoch 16/300
# 4/4 [==============================] - 3s 866ms/step - loss: 0.6979 - acc: 0.4961 - val_loss: 0.6932 - val_acc: 0.5049
#
# Epoch 00016: val_acc improved from 0.50490 to 0.50490, saving model to model_weights.best.hdf5
# Epoch 17/300
# 4/4 [==============================] - 4s 881ms/step - loss: 0.6999 - acc: 0.4941 - val_loss: 0.6933 - val_acc: 0.5147
#
# Epoch 00017: val_acc improved from 0.50490 to 0.51471, saving model to model_weights.best.hdf5
# Epoch 18/300
# 4/4 [==============================] - 3s 871ms/step - loss: 0.6979 - acc: 0.4883 - val_loss: 0.6933 - val_acc: 0.5000
#
# Epoch 00018: val_acc did not improve
# Epoch 19/300
# 4/4 [==============================] - 4s 889ms/step - loss: 0.7012 - acc: 0.4863 - val_loss: 0.6932 - val_acc: 0.5000
#
# Epoch 00019: val_acc did not improve
# Epoch 20/300
# 4/4 [==============================] - 4s 877ms/step - loss: 0.6961 - acc: 0.5195 - val_loss: 0.6932 - val_acc: 0.5000
#
# Epoch 00020: val_acc did not improve
# Epoch 21/300
# 4/4 [==============================] - 3s 870ms/step - loss: 0.6930 - acc: 0.5098 - val_loss: 0.6932 - val_acc: 0.5000
#
# Epoch 00021: val_acc did not improve
# Epoch 22/300
# 4/4 [==============================] - 3s 868ms/step - loss: 0.6918 - acc: 0.5215 - val_loss: 0.6932 - val_acc: 0.5000
#
# Epoch 00022: val_acc did not improve
# Epoch 23/300
# 4/4 [==============================] - 4s 882ms/step - loss: 0.7022 - acc: 0.4844 - val_loss: 0.6931 - val_acc: 0.5000
#
# Epoch 00023: val_acc did not improve
# Epoch 24/300
# 4/4 [==============================] - 3s 875ms/step - loss: 0.6949 - acc: 0.5117 - val_loss: 0.6932 - val_acc: 0.5000
#
# Epoch 00024: val_acc did not improve
# Epoch 25/300
# 4/4 [==============================] - 4s 896ms/step - loss: 0.7026 - acc: 0.4531 - val_loss: 0.6932 - val_acc: 0.5000
#
# Epoch 00025: val_acc did not improve
# Epoch 26/300
# 4/4 [==============================] - 3s 875ms/step - loss: 0.6967 - acc: 0.5059 - val_loss: 0.6932 - val_acc: 0.5049
#
# Epoch 00026: val_acc did not improve
# Epoch 27/300
# 4/4 [==============================] - 4s 881ms/step - loss: 0.7017 - acc: 0.4531 - val_loss: 0.6931 - val_acc: 0.5098
#
# Epoch 00027: val_acc did not improve
# Epoch 28/300
# 4/4 [==============================] - 3s 863ms/step - loss: 0.6946 - acc: 0.5039 - val_loss: 0.6931 - val_acc: 0.4853
#
# Epoch 00028: val_acc did not improve
# Epoch 29/300
# 4/4 [==============================] - 4s 877ms/step - loss: 0.6936 - acc: 0.4941 - val_loss: 0.6931 - val_acc: 0.5000
#
# Epoch 00029: val_acc did not improve
# Epoch 30/300
# 4/4 [==============================] - 3s 875ms/step - loss: 0.6940 - acc: 0.5059 - val_loss: 0.6930 - val_acc: 0.5245
#
# Epoch 00030: val_acc improved from 0.51471 to 0.52451, saving model to model_weights.best.hdf5
# Epoch 31/300
# 4/4 [==============================] - 3s 874ms/step - loss: 0.7011 - acc: 0.4727 - val_loss: 0.6929 - val_acc: 0.5343
#
# Epoch 00031: val_acc improved from 0.52451 to 0.53431, saving model to model_weights.best.hdf5
# Epoch 32/300
# 4/4 [==============================] - 3s 862ms/step - loss: 0.6920 - acc: 0.5352 - val_loss: 0.6929 - val_acc: 0.5343
#
# Epoch 00032: val_acc did not improve
# Epoch 33/300
# 4/4 [==============================] - 4s 889ms/step - loss: 0.6963 - acc: 0.4609 - val_loss: 0.6930 - val_acc: 0.5196
#
# Epoch 00033: val_acc did not improve
# Epoch 34/300
# 4/4 [==============================] - 4s 875ms/step - loss: 0.6984 - acc: 0.4707 - val_loss: 0.6931 - val_acc: 0.5049
#
# Epoch 00034: val_acc did not improve
# Epoch 35/300
# 4/4 [==============================] - 3s 871ms/step - loss: 0.6955 - acc: 0.4980 - val_loss: 0.6931 - val_acc: 0.5049
#
# Epoch 00035: val_acc did not improve
# Epoch 36/300
# 4/4 [==============================] - 4s 882ms/step - loss: 0.6940 - acc: 0.5020 - val_loss: 0.6931 - val_acc: 0.5049
#
# Epoch 00036: val_acc did not improve
# Epoch 37/300
# 4/4 [==============================] - 4s 880ms/step - loss: 0.6942 - acc: 0.4922 - val_loss: 0.6931 - val_acc: 0.5049
#
# Epoch 00037: val_acc did not improve
# Epoch 38/300
# 4/4 [==============================] - 4s 877ms/step - loss: 0.6977 - acc: 0.4688 - val_loss: 0.6932 - val_acc: 0.5049
#
# Epoch 00038: val_acc did not improve
# Epoch 39/300
# 4/4 [==============================] - 4s 890ms/step - loss: 0.6972 - acc: 0.4473 - val_loss: 0.6931 - val_acc: 0.5049
#
# Epoch 00039: val_acc did not improve
# Epoch 40/300
# 4/4 [==============================] - 3s 875ms/step - loss: 0.6932 - acc: 0.5234 - val_loss: 0.6930 - val_acc: 0.5000
#
# Epoch 00040: val_acc did not improve
# Epoch 41/300
# 4/4 [==============================] - 4s 880ms/step - loss: 0.6948 - acc: 0.4902 - val_loss: 0.6930 - val_acc: 0.5147
#
# Epoch 00041: val_acc did not improve
# Epoch 42/300
# 4/4 [==============================] - 3s 873ms/step - loss: 0.6932 - acc: 0.5117 - val_loss: 0.6930 - val_acc: 0.5490
#
# Epoch 00042: val_acc improved from 0.53431 to 0.54902, saving model to model_weights.best.hdf5
# Epoch 43/300
# 4/4 [==============================] - 4s 881ms/step - loss: 0.6937 - acc: 0.4668 - val_loss: 0.6929 - val_acc: 0.5588
#
# Epoch 00043: val_acc improved from 0.54902 to 0.55882, saving model to model_weights.best.hdf5
# Epoch 44/300
# 4/4 [==============================] - 3s 871ms/step - loss: 0.6924 - acc: 0.5176 - val_loss: 0.6930 - val_acc: 0.5441
#
# Epoch 00044: val_acc did not improve
# Epoch 45/300
# 4/4 [==============================] - 4s 900ms/step - loss: 0.6938 - acc: 0.4961 - val_loss: 0.6930 - val_acc: 0.5098
#
# Epoch 00045: val_acc did not improve
# Epoch 46/300
# 4/4 [==============================] - 4s 885ms/step - loss: 0.6922 - acc: 0.5332 - val_loss: 0.6931 - val_acc: 0.5000
#
# Epoch 00046: val_acc did not improve
# Epoch 47/300
# 4/4 [==============================] - 4s 886ms/step - loss: 0.6962 - acc: 0.4941 - val_loss: 0.6931 - val_acc: 0.5049
#
# Epoch 00047: val_acc did not improve
# Epoch 48/300
# 4/4 [==============================] - 3s 867ms/step - loss: 0.6936 - acc: 0.5215 - val_loss: 0.6932 - val_acc: 0.5000
#
# Epoch 00048: val_acc did not improve
# Epoch 49/300
# 4/4 [==============================] - 4s 890ms/step - loss: 0.6953 - acc: 0.4746 - val_loss: 0.6932 - val_acc: 0.4706
#
# Epoch 00049: val_acc did not improve
# Epoch 50/300
# 4/4 [==============================] - 3s 870ms/step - loss: 0.6946 - acc: 0.5020 - val_loss: 0.6933 - val_acc: 0.4902
#
# Epoch 00050: val_acc did not improve
# Epoch 51/300
# 4/4 [==============================] - 4s 878ms/step - loss: 0.6917 - acc: 0.5508 - val_loss: 0.6933 - val_acc: 0.4902
#
# Epoch 00051: val_acc did not improve
# Epoch 52/300
# 4/4 [==============================] - 4s 876ms/step - loss: 0.6912 - acc: 0.5293 - val_loss: 0.6934 - val_acc: 0.5000
#
# Epoch 00052: val_acc did not improve
# Epoch 53/300
# 4/4 [==============================] - 4s 887ms/step - loss: 0.6941 - acc: 0.4668 - val_loss: 0.6934 - val_acc: 0.5000
#
# Epoch 00053: val_acc did not improve
# Epoch 54/300
# 4/4 [==============================] - 3s 874ms/step - loss: 0.6955 - acc: 0.4785 - val_loss: 0.6934 - val_acc: 0.5000
#
# Epoch 00054: val_acc did not improve
# Epoch 55/300
# 4/4 [==============================] - 4s 894ms/step - loss: 0.6923 - acc: 0.4707 - val_loss: 0.6934 - val_acc: 0.5000
#
# Epoch 00055: val_acc did not improve
# Epoch 56/300
# 4/4 [==============================] - 4s 876ms/step - loss: 0.6949 - acc: 0.4824 - val_loss: 0.6932 - val_acc: 0.5000
#
# Epoch 00056: val_acc did not improve
# Epoch 57/300
# 4/4 [==============================] - 4s 881ms/step - loss: 0.6937 - acc: 0.5156 - val_loss: 0.6932 - val_acc: 0.5000
#
# Epoch 00057: val_acc did not improve
# Epoch 58/300
# 4/4 [==============================] - 3s 866ms/step - loss: 0.6935 - acc: 0.4922 - val_loss: 0.6930 - val_acc: 0.5000
#
# Epoch 00058: val_acc did not improve
# Epoch 59/300
# 4/4 [==============================] - 4s 892ms/step - loss: 0.6952 - acc: 0.5137 - val_loss: 0.6929 - val_acc: 0.5049
#
# Epoch 00059: val_acc did not improve
# Epoch 60/300
# 4/4 [==============================] - 3s 869ms/step - loss: 0.6917 - acc: 0.5293 - val_loss: 0.6927 - val_acc: 0.5196
#
# Epoch 00060: val_acc did not improve
# Epoch 61/300
# 4/4 [==============================] - 3s 873ms/step - loss: 0.6962 - acc: 0.4902 - val_loss: 0.6927 - val_acc: 0.5294
#
# Epoch 00061: val_acc did not improve
# Epoch 62/300
# 4/4 [==============================] - 3s 867ms/step - loss: 0.6940 - acc: 0.5176 - val_loss: 0.6927 - val_acc: 0.5294
#
# Epoch 00062: val_acc did not improve
# Epoch 63/300
# 4/4 [==============================] - 4s 885ms/step - loss: 0.6926 - acc: 0.5098 - val_loss: 0.6927 - val_acc: 0.5147
#
# Epoch 00063: val_acc did not improve
# Epoch 64/300
# 4/4 [==============================] - 3s 873ms/step - loss: 0.6942 - acc: 0.4883 - val_loss: 0.6928 - val_acc: 0.5098
#
# Epoch 00064: val_acc did not improve
# Epoch 65/300
# 4/4 [==============================] - 4s 879ms/step - loss: 0.6978 - acc: 0.4727 - val_loss: 0.6928 - val_acc: 0.5049
#
# Epoch 00065: val_acc did not improve
# Epoch 66/300
# 4/4 [==============================] - 3s 866ms/step - loss: 0.6933 - acc: 0.5273 - val_loss: 0.6930 - val_acc: 0.5000
#
# Epoch 00066: val_acc did not improve
# Epoch 67/300
# 4/4 [==============================] - 4s 902ms/step - loss: 0.6947 - acc: 0.5254 - val_loss: 0.6931 - val_acc: 0.5000
#
# Epoch 00067: val_acc did not improve
# Epoch 68/300
# 4/4 [==============================] - 4s 876ms/step - loss: 0.6913 - acc: 0.5469 - val_loss: 0.6930 - val_acc: 0.5000
#
# Epoch 00068: val_acc did not improve
# Epoch 69/300
# 4/4 [==============================] - 4s 889ms/step - loss: 0.6899 - acc: 0.5371 - val_loss: 0.6931 - val_acc: 0.5000
#
# Epoch 00069: val_acc did not improve
# Epoch 70/300
# 4/4 [==============================] - 3s 867ms/step - loss: 0.6950 - acc: 0.4844 - val_loss: 0.6931 - val_acc: 0.5000
#
# Epoch 00070: val_acc did not improve
# Epoch 71/300
# 4/4 [==============================] - 4s 885ms/step - loss: 0.6932 - acc: 0.5059 - val_loss: 0.6931 - val_acc: 0.5000
#
# Epoch 00071: val_acc did not improve
# Epoch 72/300
# 4/4 [==============================] - 4s 880ms/step - loss: 0.6901 - acc: 0.5508 - val_loss: 0.6931 - val_acc: 0.4951
#
# Epoch 00072: val_acc did not improve
# Epoch 73/300
# 4/4 [==============================] - 4s 879ms/step - loss: 0.6941 - acc: 0.4824 - val_loss: 0.6931 - val_acc: 0.5049
#
# Epoch 00073: val_acc did not improve
# Epoch 74/300
# 4/4 [==============================] - 4s 878ms/step - loss: 0.6933 - acc: 0.5371 - val_loss: 0.6931 - val_acc: 0.5196
#
# Epoch 00074: val_acc did not improve
# Epoch 75/300
# 4/4 [==============================] - 4s 894ms/step - loss: 0.6945 - acc: 0.4902 - val_loss: 0.6931 - val_acc: 0.5147
#
# Epoch 00075: val_acc did not improve
# Epoch 76/300
# 4/4 [==============================] - 4s 884ms/step - loss: 0.6962 - acc: 0.4824 - val_loss: 0.6931 - val_acc: 0.5147
#
# Epoch 00076: val_acc did not improve
# Epoch 77/300
# 4/4 [==============================] - 4s 895ms/step - loss: 0.6959 - acc: 0.4785 - val_loss: 0.6931 - val_acc: 0.4902
#
# Epoch 00077: val_acc did not improve
# Epoch 78/300
# 4/4 [==============================] - 4s 885ms/step - loss: 0.6941 - acc: 0.5234 - val_loss: 0.6931 - val_acc: 0.5196
#
# Epoch 00078: val_acc did not improve
# Epoch 79/300
# 4/4 [==============================] - 4s 895ms/step - loss: 0.6958 - acc: 0.4824 - val_loss: 0.6931 - val_acc: 0.5294
#
# Epoch 00079: val_acc did not improve
# Epoch 80/300
# 4/4 [==============================] - 3s 873ms/step - loss: 0.6938 - acc: 0.4824 - val_loss: 0.6931 - val_acc: 0.5000
#
# Epoch 00080: val_acc did not improve
# Epoch 81/300
# 4/4 [==============================] - 4s 878ms/step - loss: 0.6947 - acc: 0.4863 - val_loss: 0.6931 - val_acc: 0.5343
#
# Epoch 00081: val_acc did not improve
# Epoch 82/300
# 4/4 [==============================] - 4s 882ms/step - loss: 0.6944 - acc: 0.4941 - val_loss: 0.6930 - val_acc: 0.5098
#
# Epoch 00082: val_acc did not improve
# Epoch 83/300
# 4/4 [==============================] - 4s 889ms/step - loss: 0.6921 - acc: 0.5234 - val_loss: 0.6930 - val_acc: 0.5294
#
# Epoch 00083: val_acc did not improve
# Epoch 84/300
# 4/4 [==============================] - 4s 883ms/step - loss: 0.6947 - acc: 0.4609 - val_loss: 0.6930 - val_acc: 0.5049
#
# Epoch 00084: val_acc did not improve
# Epoch 85/300
# 4/4 [==============================] - 3s 868ms/step - loss: 0.6919 - acc: 0.5176 - val_loss: 0.6930 - val_acc: 0.5196
#
# Epoch 00085: val_acc did not improve
# Epoch 86/300
# 4/4 [==============================] - 4s 881ms/step - loss: 0.6971 - acc: 0.4551 - val_loss: 0.6930 - val_acc: 0.5147
#
# Epoch 00086: val_acc did not improve
# Epoch 87/300
# 4/4 [==============================] - 3s 872ms/step - loss: 0.6944 - acc: 0.4941 - val_loss: 0.6931 - val_acc: 0.5098
#
# Epoch 00087: val_acc did not improve
# Epoch 88/300
# 4/4 [==============================] - 4s 880ms/step - loss: 0.6940 - acc: 0.5000 - val_loss: 0.6931 - val_acc: 0.5147
#
# Epoch 00088: val_acc did not improve
# Epoch 89/300
# 4/4 [==============================] - 4s 876ms/step - loss: 0.6923 - acc: 0.5020 - val_loss: 0.6931 - val_acc: 0.5049
#
# Epoch 00089: val_acc did not improve
# Epoch 90/300
# 4/4 [==============================] - 3s 866ms/step - loss: 0.6939 - acc: 0.5039 - val_loss: 0.6930 - val_acc: 0.5098
#
# Epoch 00090: val_acc did not improve
# Epoch 91/300
# 4/4 [==============================] - 3s 873ms/step - loss: 0.6930 - acc: 0.5000 - val_loss: 0.6930 - val_acc: 0.5343
#
# Epoch 00091: val_acc did not improve
# Epoch 92/300
# 4/4 [==============================] - 3s 872ms/step - loss: 0.6952 - acc: 0.4863 - val_loss: 0.6930 - val_acc: 0.5245
#
# Epoch 00092: val_acc did not improve
# Epoch 93/300
# 4/4 [==============================] - 4s 892ms/step - loss: 0.6943 - acc: 0.4922 - val_loss: 0.6930 - val_acc: 0.5049
#
# Epoch 00093: val_acc did not improve
# Epoch 94/300
# 4/4 [==============================] - 3s 872ms/step - loss: 0.6932 - acc: 0.4863 - val_loss: 0.6930 - val_acc: 0.5147
#
# Epoch 00094: val_acc did not improve
# Epoch 95/300
# 4/4 [==============================] - 4s 888ms/step - loss: 0.6934 - acc: 0.5020 - val_loss: 0.6930 - val_acc: 0.5245
#
# Epoch 00095: val_acc did not improve
# Epoch 96/300
# 4/4 [==============================] - 4s 878ms/step - loss: 0.6931 - acc: 0.4805 - val_loss: 0.6930 - val_acc: 0.5294
#
# Epoch 00096: val_acc did not improve
# Epoch 97/300
# 4/4 [==============================] - 4s 892ms/step - loss: 0.6939 - acc: 0.4961 - val_loss: 0.6929 - val_acc: 0.5196
#
# Epoch 00097: val_acc did not improve
# Epoch 98/300
# 4/4 [==============================] - 3s 869ms/step - loss: 0.6917 - acc: 0.5293 - val_loss: 0.6929 - val_acc: 0.5392
#
# Epoch 00098: val_acc did not improve
# Epoch 99/300
# 4/4 [==============================] - 4s 884ms/step - loss: 0.6930 - acc: 0.5059 - val_loss: 0.6929 - val_acc: 0.5147
#
# Epoch 00099: val_acc did not improve
# Epoch 100/300
# 4/4 [==============================] - 3s 867ms/step - loss: 0.6961 - acc: 0.4570 - val_loss: 0.6930 - val_acc: 0.5147
#
# Epoch 00100: val_acc did not improve
# Epoch 101/300
# 4/4 [==============================] - 4s 882ms/step - loss: 0.6932 - acc: 0.5195 - val_loss: 0.6930 - val_acc: 0.5343
#
# Epoch 00101: val_acc did not improve
# Epoch 102/300
# 4/4 [==============================] - 3s 870ms/step - loss: 0.6925 - acc: 0.4961 - val_loss: 0.6930 - val_acc: 0.5441
#
# Epoch 00102: val_acc did not improve
# Epoch 103/300
# 4/4 [==============================] - 4s 886ms/step - loss: 0.6928 - acc: 0.5020 - val_loss: 0.6929 - val_acc: 0.5245
#
# Epoch 00103: val_acc did not improve
# Epoch 104/300
# 4/4 [==============================] - 4s 877ms/step - loss: 0.6931 - acc: 0.5000 - val_loss: 0.6929 - val_acc: 0.5245
#
# Epoch 00104: val_acc did not improve
# Epoch 105/300
# 4/4 [==============================] - 3s 873ms/step - loss: 0.6908 - acc: 0.5020 - val_loss: 0.6930 - val_acc: 0.5098
#
# Epoch 00105: val_acc did not improve
# Epoch 106/300
# 4/4 [==============================] - 3s 872ms/step - loss: 0.6934 - acc: 0.5059 - val_loss: 0.6931 - val_acc: 0.5147
#
# Epoch 00106: val_acc did not improve
# Epoch 107/300
# 4/4 [==============================] - 4s 894ms/step - loss: 0.6936 - acc: 0.4863 - val_loss: 0.6931 - val_acc: 0.5147
#
# Epoch 00107: val_acc did not improve
# Epoch 108/300
# 4/4 [==============================] - 3s 870ms/step - loss: 0.6953 - acc: 0.4863 - val_loss: 0.6931 - val_acc: 0.5245
#
# Epoch 00108: val_acc did not improve
# Epoch 109/300
# 4/4 [==============================] - 4s 891ms/step - loss: 0.6929 - acc: 0.5020 - val_loss: 0.6930 - val_acc: 0.5245
#
# Epoch 00109: val_acc did not improve
# Epoch 110/300
# 4/4 [==============================] - 4s 877ms/step - loss: 0.6914 - acc: 0.4941 - val_loss: 0.6930 - val_acc: 0.5441
#
# Epoch 00110: val_acc did not improve
# Epoch 111/300
# 4/4 [==============================] - 4s 879ms/step - loss: 0.6917 - acc: 0.5156 - val_loss: 0.6930 - val_acc: 0.5539
#
# Epoch 00111: val_acc did not improve
# Epoch 112/300
# 4/4 [==============================] - 4s 876ms/step - loss: 0.6935 - acc: 0.4922 - val_loss: 0.6929 - val_acc: 0.5539
#
# Epoch 00112: val_acc did not improve
# Epoch 113/300
# 4/4 [==============================] - 4s 875ms/step - loss: 0.6935 - acc: 0.5039 - val_loss: 0.6929 - val_acc: 0.5049
#
# Epoch 00113: val_acc did not improve
# Epoch 114/300
# 4/4 [==============================] - 4s 876ms/step - loss: 0.6909 - acc: 0.5547 - val_loss: 0.6929 - val_acc: 0.5147
#
# Epoch 00114: val_acc did not improve
# Epoch 115/300
# 4/4 [==============================] - 3s 870ms/step - loss: 0.6939 - acc: 0.4980 - val_loss: 0.6928 - val_acc: 0.5049
#
# Epoch 00115: val_acc did not improve
# Epoch 116/300
# 4/4 [==============================] - 4s 884ms/step - loss: 0.6922 - acc: 0.5078 - val_loss: 0.6928 - val_acc: 0.5098
#
# Epoch 00116: val_acc did not improve
# Epoch 117/300
# 4/4 [==============================] - 3s 865ms/step - loss: 0.6912 - acc: 0.5273 - val_loss: 0.6928 - val_acc: 0.5147
#
# Epoch 00117: val_acc did not improve
# Epoch 118/300
# 4/4 [==============================] - 3s 866ms/step - loss: 0.6918 - acc: 0.5469 - val_loss: 0.6929 - val_acc: 0.5098
#
# Epoch 00118: val_acc did not improve
# Epoch 119/300
# 4/4 [==============================] - 4s 893ms/step - loss: 0.6898 - acc: 0.5586 - val_loss: 0.6928 - val_acc: 0.5098
#
# Epoch 00119: val_acc did not improve
# Epoch 120/300
# 4/4 [==============================] - 3s 874ms/step - loss: 0.6910 - acc: 0.5176 - val_loss: 0.6927 - val_acc: 0.5245
#
# Epoch 00120: val_acc did not improve
# Epoch 121/300
# 4/4 [==============================] - 4s 885ms/step - loss: 0.6909 - acc: 0.5371 - val_loss: 0.6927 - val_acc: 0.5294
#
# Epoch 00121: val_acc did not improve
# Epoch 122/300
# 4/4 [==============================] - 4s 875ms/step - loss: 0.6928 - acc: 0.5234 - val_loss: 0.6927 - val_acc: 0.5343
#
# Epoch 00122: val_acc did not improve
# Epoch 123/300
# 4/4 [==============================] - 4s 885ms/step - loss: 0.6953 - acc: 0.4688 - val_loss: 0.6926 - val_acc: 0.5245
#
# Epoch 00123: val_acc did not improve
# Epoch 124/300
# 4/4 [==============================] - 4s 879ms/step - loss: 0.6946 - acc: 0.5059 - val_loss: 0.6925 - val_acc: 0.5343
#
# Epoch 00124: val_acc did not improve
# Epoch 125/300
# 4/4 [==============================] - 4s 895ms/step - loss: 0.6924 - acc: 0.5254 - val_loss: 0.6925 - val_acc: 0.5539
#
# Epoch 00125: val_acc did not improve
# Epoch 126/300
# 4/4 [==============================] - 4s 878ms/step - loss: 0.6912 - acc: 0.5332 - val_loss: 0.6925 - val_acc: 0.5196
#
# Epoch 00126: val_acc did not improve
# Epoch 127/300
# 4/4 [==============================] - 4s 892ms/step - loss: 0.6926 - acc: 0.5059 - val_loss: 0.6925 - val_acc: 0.5098
#
# Epoch 00127: val_acc did not improve
# Epoch 128/300
# 4/4 [==============================] - 3s 865ms/step - loss: 0.6912 - acc: 0.5234 - val_loss: 0.6925 - val_acc: 0.5343
#
# Epoch 00128: val_acc did not improve
# Epoch 129/300
# 4/4 [==============================] - 4s 879ms/step - loss: 0.6919 - acc: 0.5195 - val_loss: 0.6925 - val_acc: 0.5196
#
# Epoch 00129: val_acc did not improve
# Epoch 130/300
# 4/4 [==============================] - 3s 870ms/step - loss: 0.6885 - acc: 0.5488 - val_loss: 0.6925 - val_acc: 0.5000
#
# Epoch 00130: val_acc did not improve
# Epoch 131/300
# 4/4 [==============================] - 4s 888ms/step - loss: 0.6914 - acc: 0.5039 - val_loss: 0.6924 - val_acc: 0.4853
#
# Epoch 00131: val_acc did not improve
# Epoch 132/300
# 4/4 [==============================] - 3s 860ms/step - loss: 0.6919 - acc: 0.5332 - val_loss: 0.6924 - val_acc: 0.5000
#
# Epoch 00132: val_acc did not improve
# Epoch 133/300
# 4/4 [==============================] - 4s 906ms/step - loss: 0.6938 - acc: 0.5059 - val_loss: 0.6923 - val_acc: 0.4951
#
# Epoch 00133: val_acc did not improve
# Epoch 134/300
# 4/4 [==============================] - 3s 863ms/step - loss: 0.6917 - acc: 0.5137 - val_loss: 0.6922 - val_acc: 0.4951
#
# Epoch 00134: val_acc did not improve
# Epoch 135/300
# 4/4 [==============================] - 4s 882ms/step - loss: 0.6895 - acc: 0.5352 - val_loss: 0.6922 - val_acc: 0.5196
#
# Epoch 00135: val_acc did not improve
# Epoch 136/300
# 4/4 [==============================] - 3s 871ms/step - loss: 0.6913 - acc: 0.5312 - val_loss: 0.6921 - val_acc: 0.5196
#
# Epoch 00136: val_acc did not improve
# Epoch 137/300
# 4/4 [==============================] - 4s 880ms/step - loss: 0.6933 - acc: 0.4883 - val_loss: 0.6921 - val_acc: 0.5245
#
# Epoch 00137: val_acc did not improve
# Epoch 138/300
# 4/4 [==============================] - 3s 872ms/step - loss: 0.6884 - acc: 0.5449 - val_loss: 0.6920 - val_acc: 0.5098
#
# Epoch 00138: val_acc did not improve
# Epoch 139/300
# 4/4 [==============================] - 4s 881ms/step - loss: 0.6884 - acc: 0.5371 - val_loss: 0.6920 - val_acc: 0.5049
#
# Epoch 00139: val_acc did not improve
# Epoch 140/300
# 4/4 [==============================] - 4s 876ms/step - loss: 0.6921 - acc: 0.5234 - val_loss: 0.6919 - val_acc: 0.5245
#
# Epoch 00140: val_acc did not improve
# Epoch 141/300
# 4/4 [==============================] - 4s 881ms/step - loss: 0.6916 - acc: 0.5000 - val_loss: 0.6920 - val_acc: 0.5098
#
# Epoch 00141: val_acc did not improve
# Epoch 142/300
# 4/4 [==============================] - 3s 870ms/step - loss: 0.6909 - acc: 0.5117 - val_loss: 0.6919 - val_acc: 0.5000
#
# Epoch 00142: val_acc did not improve
# Epoch 143/300
# 4/4 [==============================] - 4s 877ms/step - loss: 0.6909 - acc: 0.5469 - val_loss: 0.6918 - val_acc: 0.5294
#
# Epoch 00143: val_acc did not improve
# Epoch 144/300
# 4/4 [==============================] - 4s 884ms/step - loss: 0.6880 - acc: 0.5449 - val_loss: 0.6917 - val_acc: 0.5245
#
# Epoch 00144: val_acc did not improve
# Epoch 145/300
# 4/4 [==============================] - 4s 889ms/step - loss: 0.6897 - acc: 0.5527 - val_loss: 0.6916 - val_acc: 0.5294
#
# Epoch 00145: val_acc did not improve
# Epoch 146/300
# 4/4 [==============================] - 4s 877ms/step - loss: 0.6896 - acc: 0.5371 - val_loss: 0.6915 - val_acc: 0.5196
#
# Epoch 00146: val_acc did not improve
# Epoch 147/300
# 4/4 [==============================] - 3s 872ms/step - loss: 0.6894 - acc: 0.5371 - val_loss: 0.6915 - val_acc: 0.5196
#
# Epoch 00147: val_acc did not improve
# Epoch 148/300
# 4/4 [==============================] - 3s 869ms/step - loss: 0.6935 - acc: 0.4922 - val_loss: 0.6915 - val_acc: 0.5343
#
# Epoch 00148: val_acc did not improve
# Epoch 149/300
# 4/4 [==============================] - 4s 891ms/step - loss: 0.6927 - acc: 0.5059 - val_loss: 0.6915 - val_acc: 0.5392
#
# Epoch 00149: val_acc did not improve
# Epoch 150/300
# 4/4 [==============================] - 3s 874ms/step - loss: 0.6865 - acc: 0.5781 - val_loss: 0.6914 - val_acc: 0.5392
#
# Epoch 00150: val_acc did not improve
# Epoch 151/300
# 4/4 [==============================] - 4s 888ms/step - loss: 0.6895 - acc: 0.5195 - val_loss: 0.6913 - val_acc: 0.5196
#
# Epoch 00151: val_acc did not improve
# Epoch 152/300
# 4/4 [==============================] - 4s 885ms/step - loss: 0.6868 - acc: 0.5469 - val_loss: 0.6912 - val_acc: 0.5196
#
# Epoch 00152: val_acc did not improve
# Epoch 153/300
# 4/4 [==============================] - 4s 876ms/step - loss: 0.6914 - acc: 0.5254 - val_loss: 0.6911 - val_acc: 0.5343
#
# Epoch 00153: val_acc did not improve
# Epoch 154/300
# 4/4 [==============================] - 3s 870ms/step - loss: 0.6870 - acc: 0.5723 - val_loss: 0.6910 - val_acc: 0.5245
#
# Epoch 00154: val_acc did not improve
# Epoch 155/300
# 4/4 [==============================] - 4s 890ms/step - loss: 0.6869 - acc: 0.5527 - val_loss: 0.6910 - val_acc: 0.5392
#
# Epoch 00155: val_acc did not improve
# Epoch 156/300
# 4/4 [==============================] - 3s 869ms/step - loss: 0.6910 - acc: 0.4961 - val_loss: 0.6911 - val_acc: 0.5196
#
# Epoch 00156: val_acc did not improve
# Epoch 157/300
# 4/4 [==============================] - 4s 882ms/step - loss: 0.6856 - acc: 0.5586 - val_loss: 0.6910 - val_acc: 0.5490
#
# Epoch 00157: val_acc did not improve
# Epoch 158/300
# 4/4 [==============================] - 4s 880ms/step - loss: 0.6879 - acc: 0.5215 - val_loss: 0.6910 - val_acc: 0.5343
#
# Epoch 00158: val_acc did not improve
# Epoch 159/300
# 4/4 [==============================] - 4s 876ms/step - loss: 0.6875 - acc: 0.5410 - val_loss: 0.6909 - val_acc: 0.5294
#
# Epoch 00159: val_acc did not improve
# Epoch 160/300
# 4/4 [==============================] - 4s 878ms/step - loss: 0.6854 - acc: 0.5488 - val_loss: 0.6908 - val_acc: 0.5196
#
# Epoch 00160: val_acc did not improve
# Epoch 161/300
# 4/4 [==============================] - 4s 899ms/step - loss: 0.6862 - acc: 0.5488 - val_loss: 0.6908 - val_acc: 0.5294
#
# Epoch 00161: val_acc did not improve
# Epoch 162/300
# 4/4 [==============================] - 4s 877ms/step - loss: 0.6840 - acc: 0.5332 - val_loss: 0.6908 - val_acc: 0.5392
#
# Epoch 00162: val_acc did not improve
# Epoch 163/300
# 4/4 [==============================] - 3s 870ms/step - loss: 0.6856 - acc: 0.5430 - val_loss: 0.6908 - val_acc: 0.5343
#
# Epoch 00163: val_acc did not improve
# Epoch 164/300
# 4/4 [==============================] - 3s 874ms/step - loss: 0.6853 - acc: 0.5898 - val_loss: 0.6907 - val_acc: 0.5343
#
# Epoch 00164: val_acc did not improve
# Epoch 165/300
# 4/4 [==============================] - 3s 873ms/step - loss: 0.6862 - acc: 0.5527 - val_loss: 0.6906 - val_acc: 0.5147
#
# Epoch 00165: val_acc did not improve
# Epoch 166/300
# 4/4 [==============================] - 3s 869ms/step - loss: 0.6863 - acc: 0.5410 - val_loss: 0.6905 - val_acc: 0.5245
#
# Epoch 00166: val_acc did not improve
# Epoch 167/300
# 4/4 [==============================] - 4s 901ms/step - loss: 0.6865 - acc: 0.5410 - val_loss: 0.6905 - val_acc: 0.5196
#
# Epoch 00167: val_acc did not improve
# Epoch 168/300
# 4/4 [==============================] - 3s 872ms/step - loss: 0.6862 - acc: 0.5664 - val_loss: 0.6905 - val_acc: 0.5392
#
# Epoch 00168: val_acc did not improve
# Epoch 169/300
# 4/4 [==============================] - 3s 871ms/step - loss: 0.6875 - acc: 0.5371 - val_loss: 0.6905 - val_acc: 0.5294
#
# Epoch 00169: val_acc did not improve
# Epoch 170/300
# 4/4 [==============================] - 4s 875ms/step - loss: 0.6818 - acc: 0.5371 - val_loss: 0.6906 - val_acc: 0.5392
#
# Epoch 00170: val_acc did not improve
# Epoch 171/300
# 4/4 [==============================] - 4s 877ms/step - loss: 0.6858 - acc: 0.5449 - val_loss: 0.6904 - val_acc: 0.5392
#
# Epoch 00171: val_acc did not improve
# Epoch 172/300
# 4/4 [==============================] - 4s 880ms/step - loss: 0.6897 - acc: 0.5195 - val_loss: 0.6902 - val_acc: 0.5343
#
# Epoch 00172: val_acc did not improve
# Epoch 173/300
# 4/4 [==============================] - 3s 873ms/step - loss: 0.6883 - acc: 0.5254 - val_loss: 0.6900 - val_acc: 0.5441
#
# Epoch 00173: val_acc did not improve
# Epoch 174/300
# 4/4 [==============================] - 3s 868ms/step - loss: 0.6784 - acc: 0.5781 - val_loss: 0.6900 - val_acc: 0.5392
#
# Epoch 00174: val_acc did not improve
# Epoch 175/300
# 4/4 [==============================] - 4s 883ms/step - loss: 0.6877 - acc: 0.5215 - val_loss: 0.6900 - val_acc: 0.5441
#
# Epoch 00175: val_acc did not improve
# Epoch 176/300
# 4/4 [==============================] - 3s 870ms/step - loss: 0.6850 - acc: 0.5547 - val_loss: 0.6901 - val_acc: 0.5441
#
# Epoch 00176: val_acc did not improve
# Epoch 177/300
# 4/4 [==============================] - 4s 891ms/step - loss: 0.6881 - acc: 0.5645 - val_loss: 0.6901 - val_acc: 0.5441
#
# Epoch 00177: val_acc did not improve
# Epoch 178/300
# 4/4 [==============================] - 3s 874ms/step - loss: 0.6843 - acc: 0.5469 - val_loss: 0.6899 - val_acc: 0.5196
#
# Epoch 00178: val_acc did not improve
# Epoch 179/300
# 4/4 [==============================] - 3s 871ms/step - loss: 0.6804 - acc: 0.5742 - val_loss: 0.6898 - val_acc: 0.5245
#
# Epoch 00179: val_acc did not improve
# Epoch 180/300
# 4/4 [==============================] - 4s 875ms/step - loss: 0.6794 - acc: 0.6035 - val_loss: 0.6896 - val_acc: 0.5294
#
# Epoch 00180: val_acc did not improve
# Epoch 181/300
# 4/4 [==============================] - 4s 890ms/step - loss: 0.6846 - acc: 0.5605 - val_loss: 0.6895 - val_acc: 0.5245
#
# Epoch 00181: val_acc did not improve
# Epoch 182/300
# 4/4 [==============================] - 4s 883ms/step - loss: 0.6845 - acc: 0.5684 - val_loss: 0.6895 - val_acc: 0.5245
#
# Epoch 00182: val_acc did not improve
# Epoch 183/300
# 4/4 [==============================] - 4s 893ms/step - loss: 0.6823 - acc: 0.5469 - val_loss: 0.6897 - val_acc: 0.5539
#
# Epoch 00183: val_acc did not improve
# Epoch 184/300
# 4/4 [==============================] - 4s 876ms/step - loss: 0.6858 - acc: 0.5684 - val_loss: 0.6897 - val_acc: 0.5539
#
# Epoch 00184: val_acc did not improve
# Epoch 185/300
# 4/4 [==============================] - 4s 894ms/step - loss: 0.6783 - acc: 0.6055 - val_loss: 0.6898 - val_acc: 0.5588
#
# Epoch 00185: val_acc did not improve
# Epoch 186/300
# 4/4 [==============================] - 3s 871ms/step - loss: 0.6842 - acc: 0.5469 - val_loss: 0.6897 - val_acc: 0.5588
#
# Epoch 00186: val_acc did not improve
# Epoch 187/300
# 4/4 [==============================] - 4s 881ms/step - loss: 0.6811 - acc: 0.5430 - val_loss: 0.6893 - val_acc: 0.5294
#
# Epoch 00187: val_acc did not improve
# Epoch 188/300
# 4/4 [==============================] - 4s 877ms/step - loss: 0.6797 - acc: 0.5723 - val_loss: 0.6892 - val_acc: 0.5245
#
# Epoch 00188: val_acc did not improve
# Epoch 189/300
# 4/4 [==============================] - 4s 892ms/step - loss: 0.6796 - acc: 0.5781 - val_loss: 0.6892 - val_acc: 0.5196
#
# Epoch 00189: val_acc did not improve
# Epoch 190/300
# 4/4 [==============================] - 3s 872ms/step - loss: 0.6819 - acc: 0.5410 - val_loss: 0.6895 - val_acc: 0.5294
#
# Epoch 00190: val_acc did not improve
# Epoch 191/300
# 4/4 [==============================] - 4s 898ms/step - loss: 0.6839 - acc: 0.5664 - val_loss: 0.6896 - val_acc: 0.5294
#
# Epoch 00191: val_acc did not improve
# Epoch 192/300
# 4/4 [==============================] - 4s 875ms/step - loss: 0.6775 - acc: 0.6016 - val_loss: 0.6898 - val_acc: 0.5588
#
# Epoch 00192: val_acc improved from 0.55882 to 0.55882, saving model to model_weights.best.hdf5
# Epoch 193/300
# 4/4 [==============================] - 4s 896ms/step - loss: 0.6805 - acc: 0.5586 - val_loss: 0.6902 - val_acc: 0.5588
#
# Epoch 00193: val_acc did not improve
# Epoch 194/300
# 4/4 [==============================] - 3s 872ms/step - loss: 0.6798 - acc: 0.5469 - val_loss: 0.6906 - val_acc: 0.5588
#
# Epoch 00194: val_acc did not improve
# Epoch 195/300
# 4/4 [==============================] - 4s 884ms/step - loss: 0.6797 - acc: 0.5781 - val_loss: 0.6903 - val_acc: 0.5539
#
# Epoch 00195: val_acc did not improve
# Epoch 196/300
# 4/4 [==============================] - 3s 861ms/step - loss: 0.6797 - acc: 0.5684 - val_loss: 0.6899 - val_acc: 0.5588
#
# Epoch 00196: val_acc did not improve
# Epoch 197/300
# 4/4 [==============================] - 4s 892ms/step - loss: 0.6801 - acc: 0.5586 - val_loss: 0.6894 - val_acc: 0.5539
#
# Epoch 00197: val_acc did not improve
# Epoch 198/300
# 4/4 [==============================] - 3s 868ms/step - loss: 0.6847 - acc: 0.5293 - val_loss: 0.6891 - val_acc: 0.5490
#
# Epoch 00198: val_acc did not improve
# Epoch 199/300
# 4/4 [==============================] - 4s 883ms/step - loss: 0.6766 - acc: 0.5723 - val_loss: 0.6892 - val_acc: 0.5441
#
# Epoch 00199: val_acc did not improve
# Epoch 200/300
# 4/4 [==============================] - 3s 872ms/step - loss: 0.6740 - acc: 0.5781 - val_loss: 0.6894 - val_acc: 0.5588
#
# Epoch 00200: val_acc did not improve
# Epoch 201/300
# 4/4 [==============================] - 4s 881ms/step - loss: 0.6812 - acc: 0.5762 - val_loss: 0.6897 - val_acc: 0.5686
#
# Epoch 00201: val_acc improved from 0.55882 to 0.56863, saving model to model_weights.best.hdf5
# Epoch 202/300
# 4/4 [==============================] - 4s 891ms/step - loss: 0.6815 - acc: 0.5605 - val_loss: 0.6897 - val_acc: 0.5686
#
# Epoch 00202: val_acc did not improve
# Epoch 203/300
# 4/4 [==============================] - 4s 885ms/step - loss: 0.6728 - acc: 0.5723 - val_loss: 0.6896 - val_acc: 0.5686
#
# Epoch 00203: val_acc did not improve
# Epoch 204/300
# 4/4 [==============================] - 3s 869ms/step - loss: 0.6797 - acc: 0.5684 - val_loss: 0.6897 - val_acc: 0.5686
#
# Epoch 00204: val_acc did not improve
# Epoch 205/300
# 4/4 [==============================] - 4s 897ms/step - loss: 0.6695 - acc: 0.6191 - val_loss: 0.6899 - val_acc: 0.5735
#
# Epoch 00205: val_acc improved from 0.56863 to 0.57353, saving model to model_weights.best.hdf5
# Epoch 206/300
# 4/4 [==============================] - 3s 872ms/step - loss: 0.6731 - acc: 0.5801 - val_loss: 0.6900 - val_acc: 0.5735
#
# Epoch 00206: val_acc did not improve
# Epoch 207/300
# 4/4 [==============================] - 4s 888ms/step - loss: 0.6807 - acc: 0.5527 - val_loss: 0.6899 - val_acc: 0.5637
#
# Epoch 00207: val_acc did not improve
# Epoch 208/300
# 4/4 [==============================] - 4s 880ms/step - loss: 0.6757 - acc: 0.6055 - val_loss: 0.6900 - val_acc: 0.5686
#
# Epoch 00208: val_acc did not improve
# Epoch 209/300
# 4/4 [==============================] - 4s 879ms/step - loss: 0.6802 - acc: 0.5547 - val_loss: 0.6895 - val_acc: 0.5686
#
# Epoch 00209: val_acc did not improve
# Epoch 210/300
# 4/4 [==============================] - 3s 869ms/step - loss: 0.6711 - acc: 0.5762 - val_loss: 0.6895 - val_acc: 0.5637
#
# Epoch 00210: val_acc did not improve
# Epoch 211/300
# 4/4 [==============================] - 4s 882ms/step - loss: 0.6792 - acc: 0.5723 - val_loss: 0.6897 - val_acc: 0.5637
#
# Epoch 00211: val_acc did not improve
# Epoch 212/300
# 4/4 [==============================] - 4s 887ms/step - loss: 0.6728 - acc: 0.5879 - val_loss: 0.6906 - val_acc: 0.5735
#
# Epoch 00212: val_acc did not improve
# Epoch 213/300
# 4/4 [==============================] - 4s 890ms/step - loss: 0.6778 - acc: 0.5918 - val_loss: 0.6904 - val_acc: 0.5686
#
# Epoch 00213: val_acc did not improve
# Epoch 214/300
# 4/4 [==============================] - 4s 882ms/step - loss: 0.6748 - acc: 0.5684 - val_loss: 0.6906 - val_acc: 0.5735
#
# Epoch 00214: val_acc did not improve
# Epoch 215/300
# 4/4 [==============================] - 4s 895ms/step - loss: 0.6751 - acc: 0.5645 - val_loss: 0.6910 - val_acc: 0.5686
#
# Epoch 00215: val_acc did not improve
# Epoch 216/300
# 4/4 [==============================] - 3s 868ms/step - loss: 0.6719 - acc: 0.5820 - val_loss: 0.6904 - val_acc: 0.5735
#
# Epoch 00216: val_acc did not improve
# Epoch 217/300
# 4/4 [==============================] - 4s 878ms/step - loss: 0.6801 - acc: 0.5605 - val_loss: 0.6900 - val_acc: 0.5637
#
# Epoch 00217: val_acc did not improve
# Epoch 218/300
# 4/4 [==============================] - 3s 874ms/step - loss: 0.6713 - acc: 0.5938 - val_loss: 0.6897 - val_acc: 0.5686
#
# Epoch 00218: val_acc did not improve
# Epoch 219/300
# 4/4 [==============================] - 4s 891ms/step - loss: 0.6710 - acc: 0.5723 - val_loss: 0.6892 - val_acc: 0.5686
#
# Epoch 00219: val_acc did not improve
# Epoch 220/300
# 4/4 [==============================] - 3s 870ms/step - loss: 0.6753 - acc: 0.5781 - val_loss: 0.6893 - val_acc: 0.5686
#
# Epoch 00220: val_acc did not improve
# Epoch 221/300
# 4/4 [==============================] - 4s 898ms/step - loss: 0.6698 - acc: 0.5820 - val_loss: 0.6887 - val_acc: 0.5588
#
# Epoch 00221: val_acc did not improve
# Epoch 222/300
# 4/4 [==============================] - 3s 873ms/step - loss: 0.6744 - acc: 0.5684 - val_loss: 0.6883 - val_acc: 0.5539
#
# Epoch 00222: val_acc did not improve
# Epoch 223/300
# 4/4 [==============================] - 4s 883ms/step - loss: 0.6656 - acc: 0.6152 - val_loss: 0.6888 - val_acc: 0.5637
#
# Epoch 00223: val_acc did not improve
# Epoch 224/300
# 4/4 [==============================] - 3s 871ms/step - loss: 0.6728 - acc: 0.5996 - val_loss: 0.6899 - val_acc: 0.5686
#
# Epoch 00224: val_acc did not improve
# Epoch 225/300
# 4/4 [==============================] - 4s 877ms/step - loss: 0.6758 - acc: 0.5566 - val_loss: 0.6912 - val_acc: 0.5686
#
# Epoch 00225: val_acc did not improve
# Epoch 226/300
# 4/4 [==============================] - 3s 865ms/step - loss: 0.6620 - acc: 0.6055 - val_loss: 0.6920 - val_acc: 0.5735
#
# Epoch 00226: val_acc did not improve
# Epoch 227/300
# 4/4 [==============================] - 4s 890ms/step - loss: 0.6681 - acc: 0.5840 - val_loss: 0.6937 - val_acc: 0.5637
#
# Epoch 00227: val_acc did not improve
# Epoch 228/300
# 4/4 [==============================] - 3s 869ms/step - loss: 0.6625 - acc: 0.6016 - val_loss: 0.6943 - val_acc: 0.5588
#
# Epoch 00228: val_acc did not improve
# Epoch 229/300
# 4/4 [==============================] - 4s 877ms/step - loss: 0.6679 - acc: 0.5840 - val_loss: 0.6928 - val_acc: 0.5686
#
# Epoch 00229: val_acc did not improve
# Epoch 230/300
# 4/4 [==============================] - 4s 877ms/step - loss: 0.6742 - acc: 0.6055 - val_loss: 0.6919 - val_acc: 0.5686
#
# Epoch 00230: val_acc did not improve
# Epoch 231/300
# 4/4 [==============================] - 4s 886ms/step - loss: 0.6774 - acc: 0.5547 - val_loss: 0.6910 - val_acc: 0.5784
#
# Epoch 00231: val_acc improved from 0.57353 to 0.57843, saving model to model_weights.best.hdf5
# Epoch 232/300
# 4/4 [==============================] - 4s 885ms/step - loss: 0.6695 - acc: 0.6035 - val_loss: 0.6907 - val_acc: 0.5735
#
# Epoch 00232: val_acc did not improve
# Epoch 233/300
# 4/4 [==============================] - 4s 880ms/step - loss: 0.6747 - acc: 0.5801 - val_loss: 0.6911 - val_acc: 0.5784
#
# Epoch 00233: val_acc did not improve
# Epoch 234/300
# 4/4 [==============================] - 4s 891ms/step - loss: 0.6662 - acc: 0.5762 - val_loss: 0.6919 - val_acc: 0.5686
#
# Epoch 00234: val_acc did not improve
# Epoch 235/300
# 4/4 [==============================] - 4s 880ms/step - loss: 0.6812 - acc: 0.5625 - val_loss: 0.6932 - val_acc: 0.5735
#
# Epoch 00235: val_acc did not improve
# Epoch 236/300
# 4/4 [==============================] - 4s 879ms/step - loss: 0.6636 - acc: 0.6094 - val_loss: 0.6940 - val_acc: 0.5735
# Epoch 00236: val_acc did not improve
# Epoch 237/300
# 4/4 [==============================] - 3s 869ms/step - loss: 0.6656 - acc: 0.6191 - val_loss: 0.6925 - val_acc: 0.5735
#
# Epoch 00237: val_acc did not improve
# Epoch 238/300
# 4/4 [==============================] - 4s 878ms/step - loss: 0.6815 - acc: 0.5449 - val_loss: 0.6915 - val_acc: 0.5686
#
# Epoch 00238: val_acc did not improve
# Epoch 239/300
# 4/4 [==============================] - 3s 871ms/step - loss: 0.6769 - acc: 0.5605 - val_loss: 0.6919 - val_acc: 0.5735
#
# Epoch 00239: val_acc did not improve
# Epoch 240/300
# 4/4 [==============================] - 4s 875ms/step - loss: 0.6616 - acc: 0.6465 - val_loss: 0.6917 - val_acc: 0.5735
#
# Epoch 00240: val_acc did not improve
# Epoch 241/300
# 4/4 [==============================] - 4s 885ms/step - loss: 0.6694 - acc: 0.5859 - val_loss: 0.6904 - val_acc: 0.5735
#
# Epoch 00241: val_acc did not improve
# Epoch 242/300
# 4/4 [==============================] - 4s 876ms/step - loss: 0.6705 - acc: 0.5820 - val_loss: 0.6903 - val_acc: 0.5784
#
# Epoch 00242: val_acc did not improve
# Epoch 243/300
# 4/4 [==============================] - 3s 869ms/step - loss: 0.6647 - acc: 0.5742 - val_loss: 0.6912 - val_acc: 0.5735
#
# Epoch 00243: val_acc did not improve
# Epoch 244/300
# 4/4 [==============================] - 3s 875ms/step - loss: 0.6598 - acc: 0.6348 - val_loss: 0.6931 - val_acc: 0.5784
#
# Epoch 00244: val_acc did not improve
# Epoch 245/300
# 4/4 [==============================] - 4s 884ms/step - loss: 0.6724 - acc: 0.5879 - val_loss: 0.6940 - val_acc: 0.5637
#
# Epoch 00245: val_acc did not improve
# Epoch 246/300
# 4/4 [==============================] - 3s 869ms/step - loss: 0.6620 - acc: 0.6133 - val_loss: 0.6943 - val_acc: 0.5735
#
# Epoch 00246: val_acc did not improve
# Epoch 247/300
# 4/4 [==============================] - 4s 889ms/step - loss: 0.6565 - acc: 0.5957 - val_loss: 0.6963 - val_acc: 0.5637
#
# Epoch 00247: val_acc did not improve
# Epoch 248/300
# 4/4 [==============================] - 3s 871ms/step - loss: 0.6641 - acc: 0.5977 - val_loss: 0.6958 - val_acc: 0.5637
#
# Epoch 00248: val_acc did not improve
# Epoch 249/300
# 4/4 [==============================] - 4s 881ms/step - loss: 0.6718 - acc: 0.5801 - val_loss: 0.6928 - val_acc: 0.5784
#
# Epoch 00249: val_acc did not improve
# Epoch 250/300
# 4/4 [==============================] - 4s 879ms/step - loss: 0.6651 - acc: 0.6113 - val_loss: 0.6915 - val_acc: 0.5735
#
# Epoch 00250: val_acc did not improve
# Epoch 251/300
# 4/4 [==============================] - 4s 901ms/step - loss: 0.6683 - acc: 0.5977 - val_loss: 0.6914 - val_acc: 0.5735
#
# Epoch 00251: val_acc did not improve
# Epoch 252/300
# 4/4 [==============================] - 4s 882ms/step - loss: 0.6715 - acc: 0.5859 - val_loss: 0.6919 - val_acc: 0.5784
#
# Epoch 00252: val_acc did not improve
# Epoch 253/300
# 4/4 [==============================] - 4s 884ms/step - loss: 0.6559 - acc: 0.5820 - val_loss: 0.6930 - val_acc: 0.5784
#
# Epoch 00253: val_acc did not improve
# Epoch 254/300
# 4/4 [==============================] - 3s 850ms/step - loss: 0.6634 - acc: 0.6016 - val_loss: 0.6938 - val_acc: 0.5784
#
# Epoch 00254: val_acc did not improve
# Epoch 255/300
# 4/4 [==============================] - 4s 887ms/step - loss: 0.6633 - acc: 0.6094 - val_loss: 0.6964 - val_acc: 0.5588
#
# Epoch 00255: val_acc did not improve
# Epoch 256/300
# 4/4 [==============================] - 4s 880ms/step - loss: 0.6597 - acc: 0.6328 - val_loss: 0.6959 - val_acc: 0.5686
#
# Epoch 00256: val_acc did not improve
# Epoch 257/300
# 4/4 [==============================] - 4s 886ms/step - loss: 0.6692 - acc: 0.6426 - val_loss: 0.6950 - val_acc: 0.5686
#
# Epoch 00257: val_acc did not improve
# Epoch 258/300
# 4/4 [==============================] - 4s 875ms/step - loss: 0.6712 - acc: 0.5996 - val_loss: 0.6931 - val_acc: 0.5735
#
# Epoch 00258: val_acc did not improve
# Epoch 259/300
# 4/4 [==============================] - 4s 888ms/step - loss: 0.6685 - acc: 0.5918 - val_loss: 0.6919 - val_acc: 0.5784
#
# Epoch 00259: val_acc did not improve
# Epoch 260/300
# 4/4 [==============================] - 4s 881ms/step - loss: 0.6493 - acc: 0.6055 - val_loss: 0.6907 - val_acc: 0.5882
#
# Epoch 00260: val_acc improved from 0.57843 to 0.58824, saving model to model_weights.best.hdf5
# Epoch 261/300
# 4/4 [==============================] - 4s 892ms/step - loss: 0.6561 - acc: 0.6289 - val_loss: 0.6908 - val_acc: 0.5882
#
# Epoch 00261: val_acc did not improve
# Epoch 262/300
# 4/4 [==============================] - 3s 871ms/step - loss: 0.6671 - acc: 0.6016 - val_loss: 0.6932 - val_acc: 0.5735
#
# Epoch 00262: val_acc did not improve
# Epoch 263/300
# 4/4 [==============================] - 4s 897ms/step - loss: 0.6603 - acc: 0.5977 - val_loss: 0.6929 - val_acc: 0.5735
#
# Epoch 00263: val_acc did not improve
# Epoch 264/300
# 4/4 [==============================] - 4s 876ms/step - loss: 0.6663 - acc: 0.5762 - val_loss: 0.6943 - val_acc: 0.5637
#
# Epoch 00264: val_acc did not improve
# Epoch 265/300
# 4/4 [==============================] - 4s 900ms/step - loss: 0.6617 - acc: 0.6211 - val_loss: 0.6964 - val_acc: 0.5637
#
# Epoch 00265: val_acc did not improve
# Epoch 266/300
# 4/4 [==============================] - 4s 878ms/step - loss: 0.6655 - acc: 0.6016 - val_loss: 0.6937 - val_acc: 0.5637
#
# Epoch 00266: val_acc did not improve
# Epoch 267/300
# 4/4 [==============================] - 4s 899ms/step - loss: 0.6577 - acc: 0.6172 - val_loss: 0.6898 - val_acc: 0.5882
#
# Epoch 00267: val_acc did not improve
# Epoch 268/300
# 4/4 [==============================] - 3s 867ms/step - loss: 0.6585 - acc: 0.6016 - val_loss: 0.6878 - val_acc: 0.5784
#
# Epoch 00268: val_acc did not improve
# Epoch 269/300
# 4/4 [==============================] - 4s 887ms/step - loss: 0.6571 - acc: 0.6133 - val_loss: 0.6883 - val_acc: 0.5931
#
# Epoch 00269: val_acc improved from 0.58824 to 0.59314, saving model to model_weights.best.hdf5
# Epoch 270/300
# 4/4 [==============================] - 4s 883ms/step - loss: 0.6570 - acc: 0.6309 - val_loss: 0.6915 - val_acc: 0.5784
#
# Epoch 00270: val_acc did not improve
# Epoch 271/300
# 4/4 [==============================] - 4s 892ms/step - loss: 0.6595 - acc: 0.6211 - val_loss: 0.6941 - val_acc: 0.5637
#
# Epoch 00271: val_acc did not improve
# Epoch 272/300
# 4/4 [==============================] - 3s 873ms/step - loss: 0.6611 - acc: 0.6191 - val_loss: 0.6949 - val_acc: 0.5637
#
# Epoch 00272: val_acc did not improve
# Epoch 273/300
# 4/4 [==============================] - 4s 893ms/step - loss: 0.6577 - acc: 0.6523 - val_loss: 0.6924 - val_acc: 0.5686
#
# Epoch 00273: val_acc did not improve
# Epoch 274/300
# 4/4 [==============================] - 4s 876ms/step - loss: 0.6597 - acc: 0.5742 - val_loss: 0.6889 - val_acc: 0.5882
#
# Epoch 00274: val_acc did not improve
# Epoch 275/300
# 4/4 [==============================] - 3s 875ms/step - loss: 0.6538 - acc: 0.6133 - val_loss: 0.6887 - val_acc: 0.5833
#
# Epoch 00275: val_acc did not improve
# Epoch 276/300
# 4/4 [==============================] - 4s 883ms/step - loss: 0.6590 - acc: 0.6230 - val_loss: 0.6902 - val_acc: 0.5882
#
# Epoch 00276: val_acc did not improve
# Epoch 277/300
# 4/4 [==============================] - 4s 912ms/step - loss: 0.6468 - acc: 0.6230 - val_loss: 0.6913 - val_acc: 0.5882
#
# Epoch 00277: val_acc did not improve
# Epoch 278/300
# 4/4 [==============================] - 3s 873ms/step - loss: 0.6588 - acc: 0.5977 - val_loss: 0.6938 - val_acc: 0.5686
#
# Epoch 00278: val_acc did not improve
# Epoch 279/300
# 4/4 [==============================] - 4s 900ms/step - loss: 0.6709 - acc: 0.5977 - val_loss: 0.6949 - val_acc: 0.5735
#
# Epoch 00279: val_acc did not improve
# Epoch 280/300
# 4/4 [==============================] - 4s 886ms/step - loss: 0.6597 - acc: 0.6133 - val_loss: 0.6949 - val_acc: 0.5784
#
# Epoch 00280: val_acc did not improve
# Epoch 281/300
# 4/4 [==============================] - 4s 891ms/step - loss: 0.6604 - acc: 0.6152 - val_loss: 0.6939 - val_acc: 0.5735
#
# Epoch 00281: val_acc did not improve
# Epoch 282/300
# 4/4 [==============================] - 4s 882ms/step - loss: 0.6507 - acc: 0.6270 - val_loss: 0.6926 - val_acc: 0.5784
#
# Epoch 00282: val_acc did not improve
# Epoch 283/300
# 4/4 [==============================] - 4s 896ms/step - loss: 0.6494 - acc: 0.6328 - val_loss: 0.6919 - val_acc: 0.5833
#
# Epoch 00283: val_acc did not improve
# Epoch 284/300
# 4/4 [==============================] - 3s 872ms/step - loss: 0.6670 - acc: 0.5957 - val_loss: 0.6907 - val_acc: 0.5833
#
# Epoch 00284: val_acc did not improve
# Epoch 285/300
# 4/4 [==============================] - 4s 898ms/step - loss: 0.6510 - acc: 0.6113 - val_loss: 0.6914 - val_acc: 0.5882
#
# Epoch 00285: val_acc did not improve
# Epoch 286/300
# 4/4 [==============================] - 4s 877ms/step - loss: 0.6642 - acc: 0.5977 - val_loss: 0.6923 - val_acc: 0.5833
#
# Epoch 00286: val_acc did not improve
# Epoch 287/300
# 4/4 [==============================] - 4s 876ms/step - loss: 0.6621 - acc: 0.6191 - val_loss: 0.6923 - val_acc: 0.5833
#
# Epoch 00287: val_acc did not improve
# Epoch 288/300
# 4/4 [==============================] - 4s 878ms/step - loss: 0.6383 - acc: 0.6328 - val_loss: 0.6935 - val_acc: 0.5833
#
# Epoch 00288: val_acc did not improve
# Epoch 289/300
# 4/4 [==============================] - 4s 886ms/step - loss: 0.6499 - acc: 0.6484 - val_loss: 0.6956 - val_acc: 0.5784
#
# Epoch 00289: val_acc did not improve
# Epoch 290/300
# 4/4 [==============================] - 3s 865ms/step - loss: 0.6668 - acc: 0.6094 - val_loss: 0.6936 - val_acc: 0.5833
#
# Epoch 00290: val_acc did not improve
# Epoch 291/300
# 4/4 [==============================] - 4s 901ms/step - loss: 0.6513 - acc: 0.6309 - val_loss: 0.6903 - val_acc: 0.5784
#
# Epoch 00291: val_acc did not improve
# Epoch 292/300
# 4/4 [==============================] - 4s 880ms/step - loss: 0.6640 - acc: 0.6094 - val_loss: 0.6899 - val_acc: 0.5833
#
# Epoch 00292: val_acc did not improve
# Epoch 293/300
# 4/4 [==============================] - 4s 905ms/step - loss: 0.6552 - acc: 0.6094 - val_loss: 0.6912 - val_acc: 0.5931
#
# Epoch 00293: val_acc improved from 0.59314 to 0.59314, saving model to model_weights.best.hdf5
# Epoch 294/300
# 4/4 [==============================] - 3s 858ms/step - loss: 0.6342 - acc: 0.6465 - val_loss: 0.6919 - val_acc: 0.5980
#
# Epoch 00294: val_acc improved from 0.59314 to 0.59804, saving model to model_weights.best.hdf5
# Epoch 295/300
# 4/4 [==============================] - 4s 902ms/step - loss: 0.6670 - acc: 0.6172 - val_loss: 0.6907 - val_acc: 0.5882
#
# Epoch 00295: val_acc did not improve
# Epoch 296/300
# 4/4 [==============================] - 3s 874ms/step - loss: 0.6488 - acc: 0.6230 - val_loss: 0.6890 - val_acc: 0.5882
#
# Epoch 00296: val_acc did not improve
# Epoch 297/300
# 4/4 [==============================] - 4s 879ms/step - loss: 0.6460 - acc: 0.6680 - val_loss: 0.6893 - val_acc: 0.5931
#
# Epoch 00297: val_acc did not improve
# Epoch 298/300
# 4/4 [==============================] - 3s 872ms/step - loss: 0.6545 - acc: 0.6348 - val_loss: 0.6901 - val_acc: 0.5882
#
# Epoch 00298: val_acc did not improve
# Epoch 299/300
# 4/4 [==============================] - 4s 890ms/step - loss: 0.6609 - acc: 0.5918 - val_loss: 0.6898 - val_acc: 0.5931
#
# Epoch 00299: val_acc did not improve
# Epoch 300/300
# 4/4 [==============================] - 3s 865ms/step - loss: 0.6466 - acc: 0.6543 - val_loss: 0.6910 - val_acc: 0.5931
#
# Epoch 00300: val_acc did not improve

# %% [markdown]
# ## 5. Predictions Stats

# %% [markdown]
# ### Bechmark Testing and Stats

# %%
model_type = VGG16
model_name = model_type.__name__

bench_model.load_weights(model_name+".weights.best.hdf5")
print("Loaded model from disk")
 
score = bench_model.evaluate(X_test, y_test, verbose=0)
print("%s: %.2f%%" % (bench_model.metrics_names[1], score[1]*100))
# Out:
# Loaded model from disk
# acc: 51.56%

# %%
prediction = bench_model.predict(X_test)

columns = 4
rows = 10
fig=plt.figure(figsize=(20, 20))

for i,pred in enumerate(prediction[0:40]):
    fig.add_subplot(rows, columns, i+1)
    plt.subplots_adjust( hspace=0.70)
    
    xi = array_to_img(pre_X_test[i])
    plt.imshow(xi)
   
    if y_test[i][0] == 1:
        plt.title("FRIDGE: {:1.2f} - non-fridge: {:1.2f}".format(pred[0],pred[1]))
    else:
        plt.title("frige: {:1.2f} - NON-FRIDGE: {:1.2f}".format(pred[0],pred[1]))

# %% [markdown]
# #### Confusion Matrix and F1-Score

# %%
def generate_f1_score(prediction, y):
    predicted_labels = [np.argmax(y_hat) for y_hat in prediction]
    print(prediction.shape)
    matrix = dict()

    matrix['fridge'] = dict()
    matrix['non-fridge'] = dict()


    matrix['fridge']['fridge'] = 0
    matrix['fridge']['non-fridge'] = 0
    matrix['non-fridge']['fridge'] = 0
    matrix['non-fridge']['non-fridge'] = 0


    for i in range(len(predicted_labels)):
        matrix['fridge']['fridge'] += int(predicted_labels[i] == 0 and y[i][0] == 1)
        matrix['fridge']['non-fridge'] += int(predicted_labels[i] == 1 and y[i][0] == 1)
        matrix['non-fridge']['fridge'] += int(predicted_labels[i] == 0 and y[i][1] == 1)
        matrix['non-fridge']['non-fridge'] += int(predicted_labels[i] == 1 and y[i][1] == 1)

    tot_fridge = matrix['fridge']['fridge']+matrix['fridge']['non-fridge']
    tot_non_fridge = matrix['non-fridge']['fridge']+matrix['non-fridge']['non-fridge']

    tot_pred_fridge = matrix['fridge']['fridge']+matrix['non-fridge']['fridge']
    tot_pred_non_fridge = matrix['non-fridge']['non-fridge']+matrix['fridge']['non-fridge']

    print('Confusion Matrix:\n')
  
    print('--------------------------------------------------------------------------')
    print('              |  fridge       | non-fridge           |   Total            ')
    print('-----------------------------------------------------|--------------------')
    print('   fridge     |      {}       |     {}             |          {}        |'.format(matrix['fridge']['fridge'],matrix['fridge']['non-fridge'],tot_fridge ))
    print('   non-fridge |      {}       |     {}             |           {}       |'.format(matrix['non-fridge']['fridge'],matrix['non-fridge']['non-fridge'],tot_non_fridge ))
    print('-----------------------------------------------------|-------------------')
    print('   Total      |      {}       |     {}             |                     |'.format(tot_pred_fridge,tot_pred_non_fridge ))


    # calculating the precision
    precision = matrix['fridge']['fridge'] / tot_pred_fridge

    print("\nHow many of the products predicted to go to the fridge actually needs to go in the fridge?")
    print("Precision: {0:.2f}%".format(precision*100))
    
    # calculating the recall
    recall = matrix['fridge']['fridge'] / tot_fridge

    print("\nOf the fridge items, how many were correctly predicted")
    print("Recall: {0:.2f}%".format(recall*100))
    
    # calculating f1 score
    f1_score = 2*(precision*recall / (precision+recall) )
    print("\nF1-Score: {0:.2f}".format(f1_score))
    
generate_f1_score(prediction, y_test)
# Out:
# (128, 2)
# Confusion Matrix:
#
# --------------------------------------------------------------------------
#               |  fridge       | non-fridge           |   Total
# -----------------------------------------------------|--------------------
#    fridge     |      17       |     45             |          62        |
#    non-fridge |      17       |     49             |           66       |
# -----------------------------------------------------|-------------------
#    Total      |      34       |     94             |                     |
#
# How many of the products predicted to go to the fridge actually needs to go in the fridge?
# Precision: 50.00%
#
# Of the fridge items, how many were correctly predicted
# Recall: 27.42%
#
# F1-Score: 0.35

# %% [markdown]
# ### Model Testing and Stats

# %%
model.load_weights("model_weights.best.hdf5")
print("Loaded model from disk")
 
score = model.evaluate_generator(test_generator)
print("%s: %.2f%%" % (model.metrics_names[1], score[1]*100))
# Out:
# Loaded model from disk
# acc: 62.32%

# %%
prediction = model.predict_generator(test_generator)
print(prediction.shape)

columns = 4
rows = 10
fig=plt.figure(figsize=(20, 20))

for i,pred in enumerate(prediction[0:40]):
    fig.add_subplot(rows, columns, i+1)
    plt.subplots_adjust( hspace=0.70)
    
    xi = array_to_img(pre_X_test[i])
    plt.imshow(xi)
    if y_test[i][0] == 1:
        plt.title("FRIDGE: {:1.2f} - non-fridge: {:1.2f}".format(pred[0],pred[1]))
    else:
        plt.title("frige: {:1.2f} - NON-FRIDGE: {:1.2f}".format(pred[0],pred[1]))
# Out:
# (138, 2)

# %%
generate_f1_score(prediction, pre_y_test)
# Out:
# (138, 2)
# Confusion Matrix:
#
# --------------------------------------------------------------------------
#               |  fridge       | non-fridge           |   Total
# -----------------------------------------------------|--------------------
#    fridge     |      29       |     40             |          69        |
#    non-fridge |      12       |     57             |           69       |
# -----------------------------------------------------|-------------------
#    Total      |      41       |     97             |                     |
#
# How many of the products predicted to go to the fridge actually needs to go in the fridge?
# Precision: 70.73%
#
# Of the fridge items, how many were correctly predicted
# Recall: 42.03%
#
# F1-Score: 0.53
